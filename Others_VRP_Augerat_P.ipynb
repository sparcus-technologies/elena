# %% [markdown]
# **This notebook has implementation and performance analysis of common algorithms for solving the vehicle routing problem on Augerat-1995 dataset set P.**

# %% [markdown]
# ---
#
#
# **Structure:**
#
# 1. Imports
# 2. Implementation:
#
# *   Neirest Neighbor
# *   LKH-3
# *   Simulated Annealing
#
# 3. Solution Routes
#
#
# ---

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import time
import glob
import os
import re
import random

from itertools import combinations
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# Data Loading

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/DNA-Insipred NNs/Input/augerat-1995-set-p.zip'
# Out:
# Archive:  /content/drive/MyDrive/DNA-Insipred NNs/Input/augerat-1995-set-p.zip
#   inflating: readme.txt
#   inflating: P-n016-k08.xml
#   inflating: P-n019-k02.xml
#   inflating: P-n020-k02.xml
#   inflating: P-n021-k02.xml
#   inflating: P-n022-k02.xml
#   inflating: P-n022-k08.xml
#   inflating: P-n023-k08.xml
#   inflating: P-n040-k05.xml
#   inflating: P-n045-k05.xml
#   inflating: P-n050-k07.xml
#   inflating: P-n050-k08.xml
#   inflating: P-n050-k10.xml
#   inflating: P-n051-k10.xml
#   inflating: P-n055-k07.xml
#   inflating: P-n055-k08.xml
#   inflating: P-n055-k10.xml
#   inflating: P-n055-k15.xml
#   inflating: P-n060-k10.xml
#   inflating: P-n060-k15.xml
#   inflating: P-n065-k10.xml
#   inflating: P-n070-k10.xml
#   inflating: P-n076-k04.xml
#   inflating: P-n076-k05.xml
#   inflating: P-n101-k04.xml

# %% [markdown]
# Implementation: Neirest Neighbor

# %%
def parse_xml_file(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Parse nodes
    nodes = []
    for node in root.findall('.//node'):
        node_id = int(node.get('id'))
        node_type = int(node.get('type'))
        cx = float(node.find('cx').text)
        cy = float(node.find('cy').text)
        nodes.append((node_id, node_type, cx, cy))

    # Parse vehicle capacity
    capacity = float(root.find('.//vehicle_profile/capacity').text)

    # Extract number of vehicles from filename
    filename = os.path.basename(file_path)
    match = re.search(r'-k(\d+)', filename)
    num_vehicles = int(match.group(1)) if match else len(root.findall('.//vehicle_profile'))

    # Parse demands
    demands = [0]  # Depot has no demand
    for request in root.findall('.//request'):
        demands.append(float(request.find('quantity').text))

    return nodes, capacity, num_vehicles, demands

def create_distance_matrix(nodes):
    coordinates = np.array([(x, y) for _, _, x, y in nodes])
    return squareform(pdist(coordinates))

def nearest_neighbor_vrp(num_cities, num_vehicles, capacity, demands):
    unvisited = set(range(1, num_cities))  # Skip depot (0)
    routes = []

    for _ in range(num_vehicles):
        if not unvisited:
            break

        current_route = []
        current_capacity = capacity
        current_city = 0  # Start from depot

        while unvisited:
            # Find nearest unvisited city that fits capacity
            nearest_city = None
            min_distance = float('inf')

            for city in unvisited:
                if demands[city] <= current_capacity:
                    distance = dist_matrix[current_city, city]
                    if distance < min_distance:
                        min_distance = distance
                        nearest_city = city

            if nearest_city is None:
                break

            current_route.append(nearest_city)
            current_capacity -= demands[nearest_city]
            current_city = nearest_city
            unvisited.remove(nearest_city)

        if current_route:
            routes.append(tuple(current_route))

    return routes

def calculate_route_distance(route):
    distance = dist_matrix[0, route[0]]  # Depot to first city
    for i in range(len(route)-1):
        distance += dist_matrix[route[i], route[i+1]]
    distance += dist_matrix[route[-1], 0]  # Last city to depot
    return distance

def solve_vrp(file_path):
    # Parse XML data
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)
    num_cities = len(nodes)

    # Create distance matrix
    global dist_matrix
    dist_matrix = create_distance_matrix(nodes)

    print(f"\nSolving {os.path.basename(file_path)}")
    print(f"Number of cities: {num_cities}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    # Start timer
    start_time = time.time()

    # Run nearest neighbor algorithm
    routes = nearest_neighbor_vrp(num_cities, num_vehicles, capacity, demands)

    # Print route details
    print("\nSolution routes:")
    total_distance = 0
    for i, route in enumerate(routes, 1):
        route_distance = calculate_route_distance(route)
        total_distance += route_distance
        print(f"Route {i}: {[0] + list(route) + [0]} (Distance: {route_distance:.2f})")
    print(f"Total distance: {total_distance:.2f}")

    # Print execution time
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")


def main():
    # Get all XML files
    xml_files = glob.glob('P-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving P-n016-k08.xml
# Number of cities: 16
# Number of vehicles: 8
# Vehicle capacity: 35.0
#
# Solution routes:
# Route 1: [0, 6, 0] (Distance: 24.08)
# Route 2: [0, 1, 10, 13, 0] (Distance: 68.44)
# Route 3: [0, 2, 0] (Distance: 42.05)
# Route 4: [0, 4, 11, 0] (Distance: 57.39)
# Route 5: [0, 7, 5, 9, 0] (Distance: 75.54)
# Route 6: [0, 15, 12, 0] (Distance: 66.12)
# Route 7: [0, 14, 3, 0] (Distance: 100.91)
# Route 8: [0, 8, 0] (Distance: 64.90)
# Total distance: 499.44
# Execution time: 0.00 seconds
#
# Solving P-n019-k02.xml
# Number of cities: 19
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 6, 18, 5, 7, 2, 9, 15, 16, 0] (Distance: 129.15)
# Route 2: [0, 1, 10, 12, 14, 4, 11, 3, 8, 17, 13, 0] (Distance: 172.59)
# Total distance: 301.75
# Execution time: 0.00 seconds
#
# Solving P-n020-k02.xml
# Number of cities: 20
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 6, 19, 5, 7, 2, 13, 9, 16, 17, 0] (Distance: 137.32)
# Route 2: [0, 1, 10, 12, 15, 4, 11, 3, 8, 18, 14, 0] (Distance: 172.59)
# Total distance: 309.91
# Execution time: 0.00 seconds
#
# Solving P-n021-k02.xml
# Number of cities: 21
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 16, 1, 10, 12, 15, 4, 11, 3, 8, 18, 19, 13, 0] (Distance: 152.95)
# Route 2: [0, 6, 20, 5, 7, 2, 9, 17, 14, 0] (Distance: 103.97)
# Total distance: 256.92
# Execution time: 0.00 seconds
#
# Solving P-n022-k02.xml
# Number of cities: 22
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 16, 1, 10, 12, 15, 4, 11, 3, 8, 18, 19, 13, 0] (Distance: 152.95)
# Route 2: [0, 6, 20, 5, 21, 7, 2, 9, 17, 14, 0] (Distance: 107.29)
# Total distance: 260.24
# Execution time: 0.00 seconds
#
# Solving P-n022-k08.xml
# Number of cities: 22
# Number of vehicles: 8
# Vehicle capacity: 3000.0
#
# Solution routes:
# Route 1: [0, 14, 16, 10, 0] (Distance: 56.64)
# Route 2: [0, 12, 15, 9, 8, 0] (Distance: 96.64)
# Route 3: [0, 13, 11, 6, 0] (Distance: 87.51)
# Route 4: [0, 17, 20, 0] (Distance: 65.03)
# Route 5: [0, 18, 21, 7, 0] (Distance: 151.67)
# Route 6: [0, 19, 0] (Distance: 61.06)
# Route 7: [0, 5, 2, 0] (Distance: 99.36)
# Route 8: [0, 4, 3, 0] (Distance: 85.33)
# Total distance: 703.24
# Execution time: 0.00 seconds
#
# Solving P-n023-k08.xml
# Number of cities: 23
# Number of vehicles: 8
# Vehicle capacity: 40.0
#
# Solution routes:
# Route 1: [0, 21, 16, 1, 10, 13, 0] (Distance: 72.09)
# Route 2: [0, 6, 20, 19, 0] (Distance: 101.15)
# Route 3: [0, 2, 22, 0] (Distance: 61.09)
# Route 4: [0, 4, 11, 9, 0] (Distance: 104.90)
# Route 5: [0, 7, 5, 12, 0] (Distance: 95.16)
# Route 6: [0, 15, 3, 0] (Distance: 78.20)
# Route 7: [0, 14, 18, 0] (Distance: 106.50)
# Route 8: [0, 17, 0] (Distance: 63.56)
# Total distance: 682.65
# Execution time: 0.00 seconds
#
# Solving P-n040-k05.xml
# Number of cities: 40
# Number of vehicles: 5
# Vehicle capacity: 140.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 5, 12, 17, 37, 15, 0] (Distance: 98.44)
# Route 2: [0, 6, 14, 25, 18, 4, 19, 10, 9, 0] (Distance: 135.62)
# Route 3: [0, 22, 28, 31, 8, 26, 7, 23, 24, 13, 29, 0] (Distance: 194.37)
# Route 4: [0, 2, 16, 21, 34, 30, 39, 33, 0] (Distance: 115.35)
# Route 5: [0, 20, 35, 36, 3, 0] (Distance: 90.24)
# Total distance: 634.04
# Execution time: 0.00 seconds
#
# Solving P-n045-k05.xml
# Number of cities: 45
# Number of vehicles: 5
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 5, 12, 17, 37, 15, 10, 0] (Distance: 117.84)
# Route 2: [0, 6, 14, 25, 18, 4, 41, 19, 0] (Distance: 97.26)
# Route 3: [0, 22, 28, 31, 8, 26, 7, 23, 24, 43, 13, 40, 0] (Distance: 192.88)
# Route 4: [0, 2, 16, 9, 30, 34, 21, 29, 20, 36, 0] (Distance: 135.54)
# Route 5: [0, 44, 42, 33, 39, 35, 3, 0] (Distance: 164.93)
# Total distance: 708.44
# Execution time: 0.00 seconds
#
# Solving P-n050-k07.xml
# Number of cities: 50
# Number of vehicles: 7
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 6, 2, 1, 0] (Distance: 84.26)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 19, 13, 49, 0] (Distance: 134.70)
# Route 3: [0, 45, 29, 48, 47, 21, 28, 22, 23, 0] (Distance: 109.24)
# Route 4: [0, 30, 5, 37, 20, 15, 27, 36, 33, 0] (Distance: 139.53)
# Route 5: [0, 16, 3, 44, 32, 9, 39, 10, 0] (Distance: 85.51)
# Route 6: [0, 38, 11, 14, 31, 25, 18, 0] (Distance: 146.62)
# Route 7: [0, 43, 41, 42, 24, 0] (Distance: 103.82)
# Total distance: 803.68
# Execution time: 0.00 seconds
#
# Solving P-n050-k08.xml
# Number of cities: 50
# Number of vehicles: 8
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 6, 3, 0] (Distance: 71.63)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0] (Distance: 45.52)
# Route 3: [0, 45, 29, 48, 47, 21, 36, 23, 0] (Distance: 126.11)
# Route 4: [0, 30, 2, 28, 22, 1, 42, 0] (Distance: 97.40)
# Route 5: [0, 27, 13, 15, 5, 37, 20, 19, 49, 0] (Distance: 168.74)
# Route 6: [0, 33, 16, 44, 32, 9, 0] (Distance: 74.32)
# Route 7: [0, 39, 10, 38, 11, 25, 0] (Distance: 120.34)
# Route 8: [0, 14, 31, 18, 24, 43, 0] (Distance: 164.57)
# Total distance: 868.62
# Execution time: 0.00 seconds
#
# Solving P-n050-k10.xml
# Number of cities: 50
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 3, 0] (Distance: 57.39)
# Route 2: [0, 4, 34, 46, 8, 15, 0] (Distance: 70.72)
# Route 3: [0, 6, 2, 30, 48, 29, 0] (Distance: 56.68)
# Route 4: [0, 7, 35, 19, 14, 38, 49, 0] (Distance: 125.81)
# Route 5: [0, 45, 27, 13, 5, 37, 36, 0] (Distance: 92.16)
# Route 6: [0, 33, 1, 43, 41, 42, 23, 0] (Distance: 87.23)
# Route 7: [0, 16, 44, 32, 9, 0] (Distance: 67.33)
# Route 8: [0, 39, 10, 31, 25, 18, 0] (Distance: 112.11)
# Route 9: [0, 28, 21, 47, 20, 0] (Distance: 93.13)
# Route 10: [0, 11, 24, 22, 0] (Distance: 147.88)
# Total distance: 910.43
# Execution time: 0.00 seconds
#
# Solving P-n051-k10.xml
# Number of cities: 51
# Number of vehicles: 10
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 46, 12, 47, 4, 17, 37, 0] (Distance: 53.94)
# Route 2: [0, 27, 1, 32, 11, 38, 9, 0] (Distance: 65.62)
# Route 3: [0, 6, 48, 8, 26, 31, 36, 0] (Distance: 116.76)
# Route 4: [0, 5, 49, 10, 30, 50, 29, 0] (Distance: 89.72)
# Route 5: [0, 18, 14, 24, 22, 0] (Distance: 91.01)
# Route 6: [0, 2, 16, 21, 34, 0] (Distance: 80.45)
# Route 7: [0, 23, 7, 43, 25, 0] (Distance: 89.31)
# Route 8: [0, 15, 44, 42, 19, 41, 0] (Distance: 85.14)
# Route 9: [0, 13, 40, 45, 33, 39, 0] (Distance: 141.61)
# Route 10: [0, 28, 3, 20, 35, 0] (Distance: 93.74)
# Total distance: 907.31
# Execution time: 0.00 seconds
#
# Solving P-n055-k07.xml
# Number of cities: 55
# Number of vehicles: 7
# Vehicle capacity: 170.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 30, 0] (Distance: 68.37)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 53, 14, 0] (Distance: 74.78)
# Route 3: [0, 45, 29, 48, 47, 21, 28, 22, 1, 23, 0] (Distance: 110.40)
# Route 4: [0, 52, 27, 13, 54, 19, 11, 38, 10, 0] (Distance: 101.20)
# Route 5: [0, 33, 16, 3, 44, 32, 9, 39, 25, 49, 0] (Distance: 122.99)
# Route 6: [0, 5, 37, 20, 15, 36, 43, 41, 42, 24, 18, 0] (Distance: 190.94)
# Route 7: [0, 50, 31, 0] (Distance: 92.40)
# Total distance: 761.08
# Execution time: 0.00 seconds
#
# Solving P-n055-k08.xml
# Number of cities: 55
# Number of vehicles: 8
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 29, 0] (Distance: 81.49)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 53, 19, 49, 0] (Distance: 130.44)
# Route 3: [0, 45, 27, 52, 13, 54, 14, 11, 23, 0] (Distance: 157.29)
# Route 4: [0, 30, 48, 47, 21, 28, 22, 1, 42, 0] (Distance: 109.56)
# Route 5: [0, 33, 16, 3, 44, 32, 9, 39, 18, 0] (Distance: 111.10)
# Route 6: [0, 5, 37, 20, 15, 36, 43, 41, 24, 50, 0] (Distance: 179.99)
# Route 7: [0, 10, 38, 31, 25, 0] (Distance: 103.55)
# Total distance: 873.43
# Execution time: 0.00 seconds
#
# Solving P-n055-k10.xml
# Number of cities: 55
# Number of vehicles: 10
# Vehicle capacity: 115.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 3, 49, 0] (Distance: 81.58)
# Route 2: [0, 4, 34, 46, 8, 35, 13, 0] (Distance: 65.49)
# Route 3: [0, 6, 2, 30, 48, 47, 15, 0] (Distance: 80.36)
# Route 4: [0, 7, 53, 14, 19, 54, 29, 0] (Distance: 87.00)
# Route 5: [0, 45, 27, 52, 5, 37, 20, 0] (Distance: 92.62)
# Route 6: [0, 33, 1, 43, 41, 42, 22, 23, 0] (Distance: 104.93)
# Route 7: [0, 16, 44, 32, 9, 39, 0] (Distance: 70.21)
# Route 8: [0, 28, 21, 36, 11, 0] (Distance: 128.61)
# Route 9: [0, 10, 38, 31, 25, 50, 0] (Distance: 108.23)
# Route 10: [0, 24, 18, 0] (Distance: 81.17)
# Total distance: 900.21
# Execution time: 0.00 seconds
#
# Solving P-n055-k15.xml
# Number of cities: 55
# Number of vehicles: 15
# Vehicle capacity: 70.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 0] (Distance: 33.13)
# Route 2: [0, 4, 34, 52, 0] (Distance: 32.76)
# Route 3: [0, 17, 51, 6, 16, 0] (Distance: 52.45)
# Route 4: [0, 46, 8, 35, 7, 0] (Distance: 40.32)
# Route 5: [0, 45, 29, 48, 36, 0] (Distance: 70.65)
# Route 6: [0, 30, 2, 1, 0] (Distance: 61.33)
# Route 7: [0, 27, 13, 54, 19, 15, 0] (Distance: 90.84)
# Route 8: [0, 33, 43, 41, 23, 0] (Distance: 78.85)
# Route 9: [0, 3, 44, 32, 25, 0] (Distance: 73.07)
# Route 10: [0, 39, 9, 50, 0] (Distance: 67.57)
# Route 11: [0, 53, 14, 37, 0] (Distance: 103.73)
# Route 12: [0, 28, 21, 22, 0] (Distance: 82.42)
# Route 13: [0, 5, 47, 20, 49, 0] (Distance: 135.27)
# Route 14: [0, 10, 38, 18, 0] (Distance: 107.18)
# Route 15: [0, 11, 31, 0] (Distance: 92.66)
# Total distance: 1122.24
# Execution time: 0.00 seconds
#
# Solving P-n060-k10.xml
# Number of cities: 60
# Number of vehicles: 10
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 0] (Distance: 47.73)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0] (Distance: 45.52)
# Route 3: [0, 45, 29, 48, 47, 21, 36, 23, 0] (Distance: 126.11)
# Route 4: [0, 52, 27, 13, 54, 19, 14, 15, 0] (Distance: 110.95)
# Route 5: [0, 30, 2, 28, 22, 1, 42, 0] (Distance: 97.40)
# Route 6: [0, 33, 16, 3, 44, 32, 39, 0] (Distance: 76.50)
# Route 7: [0, 58, 10, 38, 11, 55, 49, 0] (Distance: 146.47)
# Route 8: [0, 53, 9, 25, 50, 18, 43, 0] (Distance: 145.83)
# Route 9: [0, 5, 37, 20, 57, 59, 41, 0] (Distance: 155.05)
# Route 10: [0, 24, 56, 31, 0] (Distance: 145.07)
# Total distance: 1096.63
# Execution time: 0.00 seconds
#
# Solving P-n060-k15.xml
# Number of cities: 60
# Number of vehicles: 15
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 3, 0] (Distance: 48.93)
# Route 2: [0, 4, 34, 46, 0] (Distance: 27.56)
# Route 3: [0, 17, 51, 6, 2, 0] (Distance: 43.97)
# Route 4: [0, 7, 35, 8, 52, 27, 0] (Distance: 51.49)
# Route 5: [0, 45, 29, 48, 47, 23, 0] (Distance: 103.84)
# Route 6: [0, 30, 28, 21, 0] (Distance: 63.91)
# Route 7: [0, 33, 1, 43, 41, 0] (Distance: 73.28)
# Route 8: [0, 16, 49, 24, 18, 25, 0] (Distance: 93.42)
# Route 9: [0, 58, 10, 38, 55, 0] (Distance: 112.64)
# Route 10: [0, 44, 32, 9, 0] (Distance: 56.53)
# Route 11: [0, 39, 50, 31, 19, 0] (Distance: 128.68)
# Route 12: [0, 13, 54, 57, 15, 5, 0] (Distance: 81.82)
# Route 13: [0, 53, 14, 59, 0] (Distance: 78.72)
# Route 14: [0, 11, 37, 20, 0] (Distance: 122.26)
# Route 15: [0, 22, 42, 56, 36, 0] (Distance: 139.07)
# Total distance: 1226.11
# Execution time: 0.00 seconds
#
# Solving P-n065-k10.xml
# Number of cities: 65
# Number of vehicles: 10
# Vehicle capacity: 130.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 63, 0] (Distance: 74.47)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 13, 0] (Distance: 73.15)
# Route 3: [0, 45, 29, 48, 47, 21, 28, 0] (Distance: 71.67)
# Route 4: [0, 52, 27, 15, 57, 5, 37, 20, 60, 0] (Distance: 113.54)
# Route 5: [0, 30, 2, 62, 22, 1, 43, 41, 0] (Distance: 95.13)
# Route 6: [0, 33, 16, 3, 44, 32, 50, 49, 0] (Distance: 97.44)
# Route 7: [0, 58, 10, 38, 11, 53, 0] (Distance: 71.73)
# Route 8: [0, 39, 9, 25, 55, 18, 24, 23, 42, 0] (Distance: 139.34)
# Route 9: [0, 19, 54, 14, 59, 31, 36, 0] (Distance: 203.21)
# Route 10: [0, 61, 64, 56, 0] (Distance: 114.35)
# Total distance: 1054.03
# Execution time: 0.00 seconds
#
# Solving P-n070-k10.xml
# Number of cities: 70
# Number of vehicles: 10
# Vehicle capacity: 135.0
#
# Solution routes:
# Route 1: [0, 67, 34, 46, 8, 35, 7, 26, 0] (Distance: 43.94)
# Route 2: [0, 4, 45, 29, 48, 47, 21, 0] (Distance: 64.96)
# Route 3: [0, 68, 6, 51, 17, 40, 12, 39, 55, 0] (Distance: 112.08)
# Route 4: [0, 52, 27, 13, 54, 19, 14, 53, 0] (Distance: 80.42)
# Route 5: [0, 30, 2, 62, 28, 22, 1, 23, 0] (Distance: 99.46)
# Route 6: [0, 33, 63, 16, 3, 44, 32, 50, 0] (Distance: 84.37)
# Route 7: [0, 58, 10, 38, 65, 11, 25, 0] (Distance: 116.33)
# Route 8: [0, 9, 18, 24, 49, 56, 41, 42, 69, 0] (Distance: 163.41)
# Route 9: [0, 5, 37, 20, 60, 36, 15, 57, 61, 0] (Distance: 150.42)
# Route 10: [0, 43, 64, 31, 66, 59, 0] (Distance: 198.70)
# Total distance: 1114.07
# Execution time: 0.00 seconds
#
# Solving P-n076-k04.xml
# Number of cities: 76
# Number of vehicles: 4
# Vehicle capacity: 350.0
#
# Solution routes:
# Route 1: [0, 75, 68, 6, 51, 17, 40, 12, 26, 67, 34, 46, 8, 35, 7, 53, 14, 19, 54, 72, 0] (Distance: 164.31)
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 32, 9, 25, 0] (Distance: 148.65)
# Route 3: [0, 52, 27, 13, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 1, 43, 41, 42, 64, 56, 23, 49, 18, 55, 0] (Distance: 262.34)
# Route 4: [0, 30, 2, 24, 50, 39, 58, 10, 38, 65, 11, 66, 59, 31, 0] (Distance: 221.25)
# Total distance: 796.54
# Execution time: 0.00 seconds
#
# Solving P-n076-k05.xml
# Number of cities: 76
# Number of vehicles: 5
# Vehicle capacity: 280.0
#
# Solution routes:
# Route 1: [0, 75, 68, 6, 51, 17, 40, 12, 26, 67, 34, 46, 8, 35, 7, 19, 0] (Distance: 108.85)
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 72, 0] (Distance: 131.85)
# Route 3: [0, 52, 27, 13, 54, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 1, 43, 41, 42, 0] (Distance: 190.29)
# Route 4: [0, 30, 2, 23, 56, 49, 24, 18, 50, 32, 9, 39, 58, 10, 65, 0] (Distance: 170.11)
# Route 5: [0, 53, 14, 11, 66, 38, 31, 25, 55, 59, 64, 0] (Distance: 289.74)
# Total distance: 890.85
# Execution time: 0.00 seconds
#
# Solving P-n101-k04.xml
# Number of cities: 101
# Number of vehicles: 4
# Vehicle capacity: 400.0
#
# Solution routes:
# Route 1: [0, 53, 58, 40, 21, 73, 72, 74, 22, 75, 56, 39, 23, 67, 25, 55, 54, 80, 68, 77, 3, 79, 33, 81, 9, 35, 0] (Distance: 182.94)
# Route 2: [0, 27, 28, 26, 12, 76, 50, 1, 69, 31, 88, 7, 82, 48, 47, 36, 49, 19, 11, 62, 10, 90, 32, 63, 64, 30, 70, 0] (Distance: 226.80)
# Route 3: [0, 89, 6, 94, 95, 97, 92, 59, 99, 96, 93, 85, 91, 100, 37, 98, 61, 16, 44, 14, 42, 87, 2, 57, 15, 43, 38, 17, 84, 60, 83, 46, 78, 0] (Distance: 286.03)
# Route 4: [0, 13, 5, 18, 52, 8, 45, 86, 41, 4, 24, 29, 34, 71, 66, 20, 51, 65, 0] (Distance: 300.03)
# Total distance: 995.80
# Execution time: 0.00 seconds

# %% [markdown]
# Implementation: LKH-3

# %%
class LKH_VRP:
    def __init__(self, dist_matrix, num_vehicles, capacity, demands):
        self.dist_matrix = dist_matrix
        self.num_cities = len(dist_matrix)
        self.num_vehicles = num_vehicles
        self.capacity = capacity
        self.demands = demands

    def initial_solution(self):
        unvisited = set(range(1, self.num_cities))
        routes = []

        for _ in range(self.num_vehicles):
            if not unvisited:
                break

            current_route = []
            current_capacity = self.capacity
            current_city = 0

            while unvisited:
                nearest_city = None
                min_distance = float('inf')

                for city in unvisited:
                    if self.demands[city] <= current_capacity:
                        distance = self.dist_matrix[current_city][city]
                        if distance < min_distance:
                            min_distance = distance
                            nearest_city = city

                if nearest_city is None:
                    break

                current_route.append(nearest_city)
                current_capacity -= self.demands[nearest_city]
                current_city = nearest_city
                unvisited.remove(nearest_city)

            if current_route:
                routes.append(current_route)

        return routes

    def calculate_route_length(self, route):
        length = self.dist_matrix[0][route[0]]
        for i in range(len(route) - 1):
            length += self.dist_matrix[route[i]][route[i + 1]]
        length += self.dist_matrix[route[-1]][0]
        return length

    def calculate_total_distance(self, routes):
        return sum(self.calculate_route_length(route) for route in routes)

    def is_feasible_route(self, route):
        return sum(self.demands[i] for i in route) <= self.capacity

    def two_opt_move(self, route, i, j):
        new_route = route[:i] + route[i:j+1][::-1] + route[j+1:]
        return new_route

    def three_opt_move(self, route):
        if len(route) < 3:
            return route

        best_route = route
        best_length = self.calculate_route_length(route)

        for i, j, k in combinations(range(len(route)), 3):
            if j <= i + 1 or k <= j + 1:
                continue

            # Try all possible 3-opt combinations
            segments = [route[:i+1], route[i+1:j+1], route[j+1:k+1], route[k+1:]]
            for flip1 in [False, True]:
                for flip2 in [False, True]:
                    for flip3 in [False, True]:
                        if flip1:
                            segments[1] = segments[1][::-1]
                        if flip2:
                            segments[2] = segments[2][::-1]
                        if flip3:
                            segments[3] = segments[3][::-1]

                        new_route = segments[0] + segments[1] + segments[2] + segments[3]
                        new_length = self.calculate_route_length(new_route)

                        if new_length < best_length and self.is_feasible_route(new_route):
                            best_route = new_route
                            best_length = new_length

        return best_route

    def optimize_route(self, route):
        improved = True
        best_route = route

        while improved:
            improved = False
            current_length = self.calculate_route_length(best_route)

            # Apply 2-opt
            for i in range(len(route) - 1):
                for j in range(i + 1, len(route)):
                    new_route = self.two_opt_move(best_route, i, j)
                    if (self.calculate_route_length(new_route) < current_length and
                        self.is_feasible_route(new_route)):
                        best_route = new_route
                        improved = True
                        break
                if improved:
                    break

            # Apply 3-opt
            if not improved:
                new_route = self.three_opt_move(best_route)
                if (self.calculate_route_length(new_route) < current_length and
                    self.is_feasible_route(new_route)):
                    best_route = new_route
                    improved = True

        return best_route

    def solve(self, max_iterations=100):
        best_solution = self.initial_solution()
        best_distance = self.calculate_total_distance(best_solution)

        for _ in range(max_iterations):
            current_solution = [self.optimize_route(route) for route in best_solution]
            current_distance = self.calculate_total_distance(current_solution)

            if current_distance < best_distance:
                best_solution = current_solution
                best_distance = current_distance

        return best_solution, best_distance

def solve_vrp_lkh(file_path):
    # Parse XML data
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)

    print(f"\nSolving {os.path.basename(file_path)} with LKH")
    print(f"Number of cities: {len(nodes)}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    # Create distance matrix
    dist_matrix = create_distance_matrix(nodes)

    # Start timer
    start_time = time.time()

    # Create and run LKH solver
    solver = LKH_VRP(dist_matrix, num_vehicles, capacity, demands)
    routes, total_distance = solver.solve()

    # Print route details
    print("\nSolution routes:")
    for i, route in enumerate(routes, 1):
        route_distance = solver.calculate_route_length(route)
        print(f"Route {i}: {[0] + list(route) + [0]} (Distance: {route_distance:.2f})")
    print(f"Total distance: {total_distance:.2f}")

    # Print execution time
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")

def main():
    # Get all XML files
    xml_files = glob.glob('P-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp_lkh(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving P-n016-k08.xml with LKH
# Number of cities: 16
# Number of vehicles: 8
# Vehicle capacity: 35.0
#
# Solution routes:
# Route 1: [0, 6, 0] (Distance: 24.08)
# Route 2: [0, 1, 10, 13, 0] (Distance: 68.44)
# Route 3: [0, 2, 0] (Distance: 42.05)
# Route 4: [0, 4, 11, 0] (Distance: 57.39)
# Route 5: [0, 5, 9, 7, 0] (Distance: 68.61)
# Route 6: [0, 15, 12, 0] (Distance: 66.12)
# Route 7: [0, 14, 3, 0] (Distance: 100.91)
# Route 8: [0, 8, 0] (Distance: 64.90)
# Total distance: 492.52
# Execution time: 0.01 seconds
#
# Solving P-n019-k02.xml with LKH
# Number of cities: 19
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 6, 2, 7, 16, 9, 15, 5, 18, 0] (Distance: 109.24)
# Route 2: [0, 1, 4, 11, 14, 12, 10, 3, 17, 8, 13, 0] (Distance: 157.90)
# Total distance: 267.14
# Execution time: 0.24 seconds
#
# Solving P-n020-k02.xml with LKH
# Number of cities: 20
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 19, 7, 5, 16, 9, 13, 17, 2, 6, 0] (Distance: 115.60)
# Route 2: [0, 1, 4, 11, 15, 12, 10, 3, 18, 8, 14, 0] (Distance: 157.90)
# Total distance: 273.49
# Execution time: 0.29 seconds
#
# Solving P-n021-k02.xml with LKH
# Number of cities: 21
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 16, 13, 8, 18, 19, 3, 12, 15, 11, 4, 10, 1, 0] (Distance: 131.51)
# Route 2: [0, 20, 5, 14, 17, 9, 7, 2, 6, 0] (Distance: 88.61)
# Total distance: 220.11
# Execution time: 0.48 seconds
#
# Solving P-n022-k02.xml with LKH
# Number of cities: 22
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 16, 13, 8, 18, 19, 3, 12, 15, 11, 4, 10, 1, 0] (Distance: 131.51)
# Route 2: [0, 20, 5, 14, 17, 9, 21, 7, 2, 6, 0] (Distance: 92.02)
# Total distance: 223.53
# Execution time: 0.54 seconds
#
# Solving P-n022-k08.xml with LKH
# Number of cities: 22
# Number of vehicles: 8
# Vehicle capacity: 3000.0
#
# Solution routes:
# Route 1: [0, 10, 14, 16, 0] (Distance: 56.58)
# Route 2: [0, 12, 15, 9, 8, 0] (Distance: 96.64)
# Route 3: [0, 13, 11, 6, 0] (Distance: 87.51)
# Route 4: [0, 17, 20, 0] (Distance: 65.03)
# Route 5: [0, 21, 18, 7, 0] (Distance: 141.33)
# Route 6: [0, 19, 0] (Distance: 61.06)
# Route 7: [0, 5, 2, 0] (Distance: 99.36)
# Route 8: [0, 4, 3, 0] (Distance: 85.33)
# Total distance: 692.83
# Execution time: 0.01 seconds
#
# Solving P-n023-k08.xml with LKH
# Number of cities: 23
# Number of vehicles: 8
# Vehicle capacity: 40.0
#
# Solution routes:
# Route 1: [0, 21, 13, 10, 1, 16, 0] (Distance: 71.26)
# Route 2: [0, 6, 20, 19, 0] (Distance: 101.15)
# Route 3: [0, 2, 22, 0] (Distance: 61.09)
# Route 4: [0, 11, 4, 9, 0] (Distance: 104.33)
# Route 5: [0, 5, 7, 12, 0] (Distance: 88.57)
# Route 6: [0, 15, 3, 0] (Distance: 78.20)
# Route 7: [0, 14, 18, 0] (Distance: 106.50)
# Route 8: [0, 17, 0] (Distance: 63.56)
# Total distance: 674.66
# Execution time: 0.01 seconds
#
# Solving P-n040-k05.xml with LKH
# Number of cities: 40
# Number of vehicles: 5
# Vehicle capacity: 140.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 5, 15, 37, 17, 12, 0] (Distance: 87.11)
# Route 2: [0, 9, 10, 19, 4, 18, 25, 14, 6, 0] (Distance: 135.62)
# Route 3: [0, 13, 24, 23, 7, 26, 8, 31, 28, 22, 29, 0] (Distance: 163.30)
# Route 4: [0, 33, 39, 30, 34, 21, 16, 2, 0] (Distance: 115.35)
# Route 5: [0, 20, 35, 36, 3, 0] (Distance: 90.24)
# Total distance: 591.63
# Execution time: 0.46 seconds
#
# Solving P-n045-k05.xml with LKH
# Number of cities: 45
# Number of vehicles: 5
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 10, 15, 37, 17, 5, 12, 0] (Distance: 110.66)
# Route 2: [0, 6, 14, 25, 41, 19, 4, 18, 0] (Distance: 91.46)
# Route 3: [0, 22, 28, 31, 8, 26, 7, 23, 43, 24, 13, 40, 0] (Distance: 184.65)
# Route 4: [0, 2, 20, 36, 29, 21, 34, 30, 9, 16, 0] (Distance: 128.67)
# Route 5: [0, 42, 44, 33, 39, 35, 3, 0] (Distance: 163.01)
# Total distance: 678.44
# Execution time: 0.72 seconds
#
# Solving P-n050-k07.xml with LKH
# Number of cities: 50
# Number of vehicles: 7
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 1, 2, 6, 0] (Distance: 82.62)
# Route 2: [0, 49, 4, 34, 13, 19, 35, 7, 8, 46, 0] (Distance: 129.81)
# Route 3: [0, 45, 29, 48, 47, 21, 28, 22, 23, 0] (Distance: 109.24)
# Route 4: [0, 30, 27, 15, 5, 37, 20, 36, 33, 0] (Distance: 126.45)
# Route 5: [0, 16, 3, 44, 32, 9, 39, 10, 0] (Distance: 85.51)
# Route 6: [0, 14, 11, 38, 31, 25, 18, 0] (Distance: 130.00)
# Route 7: [0, 42, 41, 43, 24, 0] (Distance: 103.55)
# Total distance: 767.19
# Execution time: 0.34 seconds
#
# Solving P-n050-k08.xml with LKH
# Number of cities: 50
# Number of vehicles: 8
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 3, 17, 6, 0] (Distance: 60.55)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0] (Distance: 45.52)
# Route 3: [0, 23, 21, 36, 47, 48, 29, 45, 0] (Distance: 115.82)
# Route 4: [0, 1, 42, 22, 28, 2, 30, 0] (Distance: 87.99)
# Route 5: [0, 19, 13, 15, 20, 37, 5, 27, 49, 0] (Distance: 156.59)
# Route 6: [0, 33, 16, 44, 32, 9, 0] (Distance: 74.32)
# Route 7: [0, 11, 38, 10, 39, 25, 0] (Distance: 102.72)
# Route 8: [0, 14, 31, 18, 24, 43, 0] (Distance: 164.57)
# Total distance: 808.07
# Execution time: 0.17 seconds
#
# Solving P-n050-k10.xml with LKH
# Number of cities: 50
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 17, 3, 40, 12, 26, 0] (Distance: 49.39)
# Route 2: [0, 34, 46, 8, 15, 4, 0] (Distance: 66.69)
# Route 3: [0, 6, 2, 30, 48, 29, 0] (Distance: 56.68)
# Route 4: [0, 7, 35, 19, 14, 38, 49, 0] (Distance: 125.81)
# Route 5: [0, 45, 36, 37, 5, 13, 27, 0] (Distance: 89.20)
# Route 6: [0, 33, 1, 42, 41, 43, 23, 0] (Distance: 86.89)
# Route 7: [0, 16, 44, 32, 9, 0] (Distance: 67.33)
# Route 8: [0, 18, 25, 31, 10, 39, 0] (Distance: 112.11)
# Route 9: [0, 28, 21, 47, 20, 0] (Distance: 93.13)
# Route 10: [0, 22, 24, 11, 0] (Distance: 147.88)
# Total distance: 895.11
# Execution time: 0.08 seconds
#
# Solving P-n051-k10.xml with LKH
# Number of cities: 51
# Number of vehicles: 10
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 46, 12, 37, 17, 4, 47, 0] (Distance: 49.32)
# Route 2: [0, 27, 1, 32, 11, 9, 38, 0] (Distance: 64.45)
# Route 3: [0, 6, 48, 8, 26, 31, 36, 0] (Distance: 116.76)
# Route 4: [0, 5, 49, 10, 30, 50, 29, 0] (Distance: 89.72)
# Route 5: [0, 22, 24, 14, 18, 0] (Distance: 91.01)
# Route 6: [0, 2, 16, 21, 34, 0] (Distance: 80.45)
# Route 7: [0, 23, 7, 43, 25, 0] (Distance: 89.31)
# Route 8: [0, 15, 44, 42, 19, 41, 0] (Distance: 85.14)
# Route 9: [0, 39, 33, 45, 40, 13, 0] (Distance: 141.61)
# Route 10: [0, 20, 35, 3, 28, 0] (Distance: 89.02)
# Total distance: 896.78
# Execution time: 0.08 seconds
#
# Solving P-n055-k07.xml with LKH
# Number of cities: 55
# Number of vehicles: 7
# Vehicle capacity: 170.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 30, 0] (Distance: 68.37)
# Route 2: [0, 7, 53, 14, 35, 8, 46, 34, 4, 0] (Distance: 66.02)
# Route 3: [0, 23, 1, 22, 28, 21, 47, 48, 29, 45, 0] (Distance: 110.40)
# Route 4: [0, 52, 27, 13, 54, 19, 11, 38, 10, 0] (Distance: 101.20)
# Route 5: [0, 39, 9, 25, 32, 44, 3, 49, 16, 33, 0] (Distance: 103.99)
# Route 6: [0, 18, 24, 41, 42, 43, 36, 37, 20, 15, 5, 0] (Distance: 180.63)
# Route 7: [0, 50, 31, 0] (Distance: 92.40)
# Total distance: 723.02
# Execution time: 0.62 seconds
#
# Solving P-n055-k08.xml with LKH
# Number of cities: 55
# Number of vehicles: 8
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 29, 0] (Distance: 81.49)
# Route 2: [0, 4, 34, 46, 8, 19, 35, 53, 7, 49, 0] (Distance: 119.80)
# Route 3: [0, 11, 14, 54, 13, 52, 27, 45, 23, 0] (Distance: 153.86)
# Route 4: [0, 1, 42, 22, 28, 21, 47, 48, 30, 0] (Distance: 100.14)
# Route 5: [0, 33, 16, 18, 9, 39, 32, 44, 3, 0] (Distance: 109.49)
# Route 6: [0, 50, 24, 41, 43, 36, 37, 20, 15, 5, 0] (Distance: 172.67)
# Route 7: [0, 38, 10, 31, 25, 0] (Distance: 99.06)
# Total distance: 836.52
# Execution time: 0.48 seconds
#
# Solving P-n055-k10.xml with LKH
# Number of cities: 55
# Number of vehicles: 10
# Vehicle capacity: 115.0
#
# Solution routes:
# Route 1: [0, 51, 49, 3, 17, 40, 12, 26, 0] (Distance: 77.22)
# Route 2: [0, 46, 35, 8, 13, 34, 4, 0] (Distance: 64.47)
# Route 3: [0, 6, 2, 30, 48, 47, 15, 0] (Distance: 80.36)
# Route 4: [0, 7, 53, 14, 19, 54, 29, 0] (Distance: 87.00)
# Route 5: [0, 45, 5, 37, 20, 27, 52, 0] (Distance: 79.57)
# Route 6: [0, 23, 43, 41, 42, 22, 1, 33, 0] (Distance: 97.16)
# Route 7: [0, 16, 44, 32, 9, 39, 0] (Distance: 70.21)
# Route 8: [0, 28, 21, 36, 11, 0] (Distance: 128.61)
# Route 9: [0, 38, 10, 31, 25, 50, 0] (Distance: 103.75)
# Route 10: [0, 24, 18, 0] (Distance: 81.17)
# Total distance: 869.51
# Execution time: 0.14 seconds
#
# Solving P-n055-k15.xml with LKH
# Number of cities: 55
# Number of vehicles: 15
# Vehicle capacity: 70.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 0] (Distance: 33.13)
# Route 2: [0, 4, 52, 34, 0] (Distance: 31.03)
# Route 3: [0, 17, 51, 16, 6, 0] (Distance: 44.39)
# Route 4: [0, 46, 8, 35, 7, 0] (Distance: 40.32)
# Route 5: [0, 45, 29, 36, 48, 0] (Distance: 67.88)
# Route 6: [0, 30, 2, 1, 0] (Distance: 61.33)
# Route 7: [0, 19, 54, 13, 15, 27, 0] (Distance: 79.18)
# Route 8: [0, 33, 43, 41, 23, 0] (Distance: 78.85)
# Route 9: [0, 3, 44, 32, 25, 0] (Distance: 73.07)
# Route 10: [0, 39, 9, 50, 0] (Distance: 67.57)
# Route 11: [0, 53, 14, 37, 0] (Distance: 103.73)
# Route 12: [0, 21, 28, 22, 0] (Distance: 76.68)
# Route 13: [0, 5, 20, 47, 49, 0] (Distance: 126.05)
# Route 14: [0, 38, 10, 18, 0] (Distance: 101.38)
# Route 15: [0, 11, 31, 0] (Distance: 92.66)
# Total distance: 1077.29
# Execution time: 0.03 seconds
#
# Solving P-n060-k10.xml with LKH
# Number of cities: 60
# Number of vehicles: 10
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 0] (Distance: 47.73)
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0] (Distance: 45.52)
# Route 3: [0, 23, 21, 36, 47, 48, 29, 45, 0] (Distance: 115.82)
# Route 4: [0, 14, 19, 54, 13, 15, 27, 52, 0] (Distance: 94.69)
# Route 5: [0, 1, 42, 22, 28, 2, 30, 0] (Distance: 87.99)
# Route 6: [0, 39, 32, 44, 3, 16, 33, 0] (Distance: 76.50)
# Route 7: [0, 11, 38, 10, 58, 55, 49, 0] (Distance: 141.97)
# Route 8: [0, 53, 9, 25, 50, 18, 43, 0] (Distance: 145.83)
# Route 9: [0, 41, 59, 5, 37, 20, 57, 0] (Distance: 147.53)
# Route 10: [0, 56, 24, 31, 0] (Distance: 133.10)
# Total distance: 1036.67
# Execution time: 0.15 seconds
#
# Solving P-n060-k15.xml with LKH
# Number of cities: 60
# Number of vehicles: 15
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 3, 0] (Distance: 48.93)
# Route 2: [0, 4, 34, 46, 0] (Distance: 27.56)
# Route 3: [0, 17, 51, 6, 2, 0] (Distance: 43.97)
# Route 4: [0, 7, 35, 8, 52, 27, 0] (Distance: 51.49)
# Route 5: [0, 45, 29, 48, 47, 23, 0] (Distance: 103.84)
# Route 6: [0, 28, 21, 30, 0] (Distance: 61.36)
# Route 7: [0, 1, 43, 41, 33, 0] (Distance: 72.88)
# Route 8: [0, 16, 49, 24, 18, 25, 0] (Distance: 93.42)
# Route 9: [0, 58, 38, 10, 55, 0] (Distance: 108.91)
# Route 10: [0, 44, 32, 9, 0] (Distance: 56.53)
# Route 11: [0, 19, 31, 39, 50, 0] (Distance: 126.42)
# Route 12: [0, 54, 13, 57, 15, 5, 0] (Distance: 80.68)
# Route 13: [0, 53, 59, 14, 0] (Distance: 77.66)
# Route 14: [0, 37, 20, 11, 0] (Distance: 119.43)
# Route 15: [0, 36, 22, 42, 56, 0] (Distance: 123.69)
# Total distance: 1196.75
# Execution time: 0.04 seconds
#
# Solving P-n065-k10.xml with LKH
# Number of cities: 65
# Number of vehicles: 10
# Vehicle capacity: 130.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 63, 6, 0] (Distance: 67.65)
# Route 2: [0, 4, 13, 8, 35, 7, 46, 34, 0] (Distance: 66.58)
# Route 3: [0, 28, 21, 47, 48, 29, 45, 0] (Distance: 71.67)
# Route 4: [0, 5, 37, 60, 20, 15, 57, 27, 52, 0] (Distance: 99.46)
# Route 5: [0, 30, 2, 62, 22, 41, 43, 1, 0] (Distance: 89.06)
# Route 6: [0, 33, 49, 50, 32, 44, 3, 16, 0] (Distance: 96.83)
# Route 7: [0, 58, 10, 38, 11, 53, 0] (Distance: 71.73)
# Route 8: [0, 39, 9, 25, 55, 18, 24, 23, 42, 0] (Distance: 139.34)
# Route 9: [0, 36, 54, 19, 14, 59, 31, 0] (Distance: 172.87)
# Route 10: [0, 56, 64, 61, 0] (Distance: 114.35)
# Total distance: 989.54
# Execution time: 0.34 seconds
#
# Solving P-n070-k10.xml with LKH
# Number of cities: 70
# Number of vehicles: 10
# Vehicle capacity: 135.0
#
# Solution routes:
# Route 1: [0, 26, 7, 35, 8, 46, 34, 67, 0] (Distance: 43.94)
# Route 2: [0, 21, 47, 48, 29, 45, 4, 0] (Distance: 64.96)
# Route 3: [0, 68, 6, 51, 55, 39, 12, 40, 17, 0] (Distance: 107.67)
# Route 4: [0, 52, 27, 13, 54, 19, 14, 53, 0] (Distance: 80.42)
# Route 5: [0, 30, 2, 62, 28, 22, 1, 23, 0] (Distance: 99.46)
# Route 6: [0, 33, 63, 16, 3, 44, 50, 32, 0] (Distance: 81.79)
# Route 7: [0, 11, 65, 38, 10, 58, 25, 0] (Distance: 110.81)
# Route 8: [0, 69, 42, 41, 56, 49, 24, 18, 9, 0] (Distance: 163.41)
# Route 9: [0, 57, 15, 20, 60, 36, 37, 5, 61, 0] (Distance: 137.77)
# Route 10: [0, 64, 43, 31, 66, 59, 0] (Distance: 195.98)
# Total distance: 1086.20
# Execution time: 0.35 seconds
#
# Solving P-n076-k04.xml with LKH
# Number of cities: 76
# Number of vehicles: 4
# Vehicle capacity: 350.0
#
# Solution routes:
# Route 1: [0, 34, 46, 8, 35, 54, 19, 14, 53, 7, 67, 26, 12, 72, 40, 17, 51, 6, 68, 75, 0] (Distance: 145.61)
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 32, 25, 9, 0] (Distance: 143.88)
# Route 3: [0, 52, 27, 13, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 64, 42, 41, 43, 1, 56, 23, 49, 18, 55, 0] (Distance: 260.44)
# Route 4: [0, 39, 58, 10, 38, 65, 11, 59, 66, 31, 50, 24, 2, 30, 0] (Distance: 209.85)
# Total distance: 759.77
# Execution time: 17.87 seconds
#
# Solving P-n076-k05.xml with LKH
# Number of cities: 76
# Number of vehicles: 5
# Vehicle capacity: 280.0
#
# Solution routes:
# Route 1: [0, 34, 46, 8, 19, 35, 7, 67, 26, 12, 40, 17, 51, 6, 68, 75, 0] (Distance: 97.22)
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 72, 0] (Distance: 131.85)
# Route 3: [0, 52, 27, 13, 54, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 42, 41, 43, 1, 0] (Distance: 180.87)
# Route 4: [0, 30, 2, 23, 56, 49, 24, 18, 50, 32, 9, 39, 58, 10, 65, 0] (Distance: 170.11)
# Route 5: [0, 64, 25, 55, 31, 38, 66, 59, 14, 11, 53, 0] (Distance: 230.83)
# Total distance: 810.89
# Execution time: 8.14 seconds
#
# Solving P-n101-k04.xml with LKH
# Number of cities: 101
# Number of vehicles: 4
# Vehicle capacity: 400.0
#
# Solution routes:
# Route 1: [0, 33, 9, 35, 81, 79, 3, 77, 68, 80, 54, 55, 25, 39, 67, 23, 56, 75, 22, 74, 72, 73, 21, 40, 58, 53, 0] (Distance: 176.23)
# Route 2: [0, 28, 26, 12, 76, 50, 1, 70, 30, 32, 90, 63, 10, 62, 19, 11, 64, 49, 36, 47, 48, 82, 7, 88, 31, 69, 27, 0] (Distance: 195.56)
# Route 3: [0, 78, 46, 83, 60, 84, 17, 61, 16, 44, 38, 14, 43, 15, 57, 2, 87, 42, 100, 91, 85, 37, 98, 93, 99, 96, 59, 92, 97, 95, 94, 6, 89, 0] (Distance: 271.49)
# Route 4: [0, 51, 20, 66, 65, 71, 34, 29, 24, 4, 41, 86, 5, 45, 8, 18, 52, 13, 0] (Distance: 261.38)
# Total distance: 904.67
# Execution time: 57.93 seconds

# %% [markdown]
# Implementation: Simulated Annealing

# %%
class SimulatedAnnealingVRP:
    def __init__(self, dist_matrix, num_vehicles, capacity, demands):
        self.dist_matrix = dist_matrix
        self.num_cities = len(dist_matrix)
        self.num_vehicles = num_vehicles
        self.capacity = capacity
        self.demands = demands

    def initial_solution(self):
        unvisited = set(range(1, self.num_cities))
        routes = []

        for _ in range(self.num_vehicles):
            if not unvisited:
                break

            current_route = []
            current_capacity = self.capacity
            current_city = 0

            while unvisited:
                nearest_city = None
                min_distance = float('inf')

                for city in unvisited:
                    if self.demands[city] <= current_capacity:
                        distance = self.dist_matrix[current_city][city]
                        if distance < min_distance:
                            min_distance = distance
                            nearest_city = city

                if nearest_city is None:
                    break

                current_route.append(nearest_city)
                current_capacity -= self.demands[nearest_city]
                current_city = nearest_city
                unvisited.remove(nearest_city)

            if current_route:
                routes.append(current_route)

        return routes

    def calculate_total_distance(self, routes):
        total_distance = 0
        for route in routes:
            if not route:  # Skip empty routes
                continue
            route_distance = self.dist_matrix[0][route[0]]
            for i in range(len(route) - 1):
                route_distance += self.dist_matrix[route[i]][route[i + 1]]
            route_distance += self.dist_matrix[route[-1]][0]
            total_distance += route_distance
        return total_distance

    def is_feasible(self, routes):
        for route in routes:
            if sum(self.demands[i] for i in route) > self.capacity:
                return False
        return True

    def generate_neighbor(self, routes):
        neighbor_routes = [list(route) for route in routes]

        if not neighbor_routes:
            return neighbor_routes

        r1 = random.randint(0, len(neighbor_routes) - 1)
        r2 = random.randint(0, len(neighbor_routes) - 1)

        if len(neighbor_routes[r1]) > 0:
            i = random.randint(0, len(neighbor_routes[r1])-1)
            if len(neighbor_routes[r2]) > 0:
                j = random.randint(0, len(neighbor_routes[r2])-1)
                if r1 == r2:
                    neighbor_routes[r1][i], neighbor_routes[r2][j] = neighbor_routes[r2][j], neighbor_routes[r1][i]
                else:
                    city = neighbor_routes[r1].pop(i)
                    neighbor_routes[r2].insert(j, city)

        neighbor_routes = [route for route in neighbor_routes if route]
        return neighbor_routes

    def solve(self, initial_temperature=1000, cooling_rate=0.99, max_iterations=1000):
        current_solution = self.initial_solution()
        current_cost = self.calculate_total_distance(current_solution)
        best_solution = current_solution.copy()
        best_cost = current_cost
        temperature = initial_temperature

        for _ in range(max_iterations):
            neighbor = self.generate_neighbor(current_solution)

            if neighbor and self.is_feasible(neighbor):
                neighbor_cost = self.calculate_total_distance(neighbor)
                cost_diff = neighbor_cost - current_cost

                if cost_diff < 0 or random.random() < np.exp(-cost_diff / temperature):
                    current_solution = neighbor
                    current_cost = neighbor_cost

                    if current_cost < best_cost:
                        best_solution = current_solution.copy()
                        best_cost = current_cost

            temperature *= cooling_rate
            if temperature < 0.1:
                break

        return best_solution, best_cost

def solve_vrp_sa(file_path):
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)

    print(f"\nSolving {os.path.basename(file_path)} with Simulated Annealing")
    print(f"Number of cities: {len(nodes)}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    dist_matrix = create_distance_matrix(nodes)

    start_time = time.time()

    solver = SimulatedAnnealingVRP(dist_matrix, num_vehicles, capacity, demands)
    routes, total_distance = solver.solve()

    print("\nSolution routes:")
    for i, route in enumerate(routes, 1):
        print(f"Route {i}: {[0] + route + [0]}")
    print(f"Total distance: {total_distance:.2f}")

    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")

def main():
    xml_files = glob.glob('P-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp_sa(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving P-n016-k08.xml with Simulated Annealing
# Number of cities: 16
# Number of vehicles: 8
# Vehicle capacity: 35.0
#
# Solution routes:
# Route 1: [0, 6, 0]
# Route 2: [0, 12, 1, 0]
# Route 3: [0, 2, 0]
# Route 4: [0, 4, 11, 0]
# Route 5: [0, 3, 9, 5, 0]
# Route 6: [0, 15, 10, 7, 0]
# Route 7: [0, 14, 0]
# Route 8: [0, 13, 8, 0]
# Total distance: 493.89
# Execution time: 0.01 seconds
#
# Solving P-n019-k02.xml with Simulated Annealing
# Number of cities: 19
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 6, 18, 7, 2, 16, 9, 15, 5, 0]
# Route 2: [0, 13, 10, 8, 17, 3, 12, 14, 11, 4, 1, 0]
# Total distance: 280.71
# Execution time: 0.01 seconds
#
# Solving P-n020-k02.xml with Simulated Annealing
# Number of cities: 20
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 7, 2, 17, 9, 16, 5, 19, 6, 0]
# Route 2: [0, 10, 3, 18, 8, 13, 14, 12, 15, 11, 4, 1, 0]
# Total distance: 295.29
# Execution time: 0.01 seconds
#
# Solving P-n021-k02.xml with Simulated Annealing
# Number of cities: 21
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 16, 1, 10, 12, 15, 4, 11, 3, 8, 18, 19, 13, 0]
# Route 2: [0, 6, 20, 5, 7, 2, 9, 17, 14, 0]
# Total distance: 256.92
# Execution time: 0.01 seconds
#
# Solving P-n022-k02.xml with Simulated Annealing
# Number of cities: 22
# Number of vehicles: 2
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 10, 12, 15, 11, 4, 3, 19, 18, 8, 13, 16, 0]
# Route 2: [0, 6, 20, 7, 5, 14, 17, 21, 9, 2, 1, 0]
# Total distance: 247.33
# Execution time: 0.01 seconds
#
# Solving P-n022-k08.xml with Simulated Annealing
# Number of cities: 22
# Number of vehicles: 8
# Vehicle capacity: 3000.0
#
# Solution routes:
# Route 1: [0, 14, 16, 10, 0]
# Route 2: [0, 12, 15, 9, 8, 0]
# Route 3: [0, 13, 11, 0]
# Route 4: [0, 17, 20, 0]
# Route 5: [0, 18, 21, 7, 6, 0]
# Route 6: [0, 19, 0]
# Route 7: [0, 5, 2, 0]
# Route 8: [0, 4, 3, 0]
# Total distance: 687.29
# Execution time: 0.01 seconds
#
# Solving P-n023-k08.xml with Simulated Annealing
# Number of cities: 23
# Number of vehicles: 8
# Vehicle capacity: 40.0
#
# Solution routes:
# Route 1: [0, 20, 5, 16, 0]
# Route 2: [0, 6, 0]
# Route 3: [0, 22, 2, 0]
# Route 4: [0, 13, 11, 4, 0]
# Route 5: [0, 1, 12, 7, 0]
# Route 6: [0, 21, 10, 3, 15, 0]
# Route 7: [0, 14, 18, 0]
# Route 8: [0, 9, 19, 17, 0]
# Total distance: 626.29
# Execution time: 0.01 seconds
#
# Solving P-n040-k05.xml with Simulated Annealing
# Number of cities: 40
# Number of vehicles: 5
# Vehicle capacity: 140.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 5, 12, 17, 37, 15, 0]
# Route 2: [0, 6, 14, 25, 18, 4, 19, 10, 9, 0]
# Route 3: [0, 22, 28, 31, 8, 26, 7, 23, 24, 13, 29, 0]
# Route 4: [0, 2, 16, 21, 34, 30, 39, 33, 0]
# Route 5: [0, 20, 35, 36, 3, 0]
# Total distance: 634.04
# Execution time: 0.02 seconds
#
# Solving P-n045-k05.xml with Simulated Annealing
# Number of cities: 45
# Number of vehicles: 5
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 27, 1, 32, 11, 38, 5, 12, 17, 37, 15, 10, 0]
# Route 2: [0, 6, 14, 25, 18, 4, 41, 19, 0]
# Route 3: [0, 22, 28, 31, 8, 26, 7, 23, 24, 43, 13, 40, 0]
# Route 4: [0, 2, 16, 9, 30, 34, 21, 29, 20, 36, 0]
# Route 5: [0, 44, 42, 33, 39, 35, 3, 0]
# Total distance: 708.44
# Execution time: 0.01 seconds
#
# Solving P-n050-k07.xml with Simulated Annealing
# Number of cities: 50
# Number of vehicles: 7
# Vehicle capacity: 150.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 6, 2, 1, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 19, 13, 49, 0]
# Route 3: [0, 45, 29, 48, 47, 21, 28, 22, 23, 0]
# Route 4: [0, 30, 5, 37, 20, 15, 27, 36, 33, 0]
# Route 5: [0, 16, 3, 44, 32, 9, 39, 10, 0]
# Route 6: [0, 38, 11, 14, 31, 25, 18, 0]
# Route 7: [0, 43, 41, 42, 24, 0]
# Total distance: 803.68
# Execution time: 0.01 seconds
#
# Solving P-n050-k08.xml with Simulated Annealing
# Number of cities: 50
# Number of vehicles: 8
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 6, 3, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0]
# Route 3: [0, 45, 29, 48, 47, 21, 36, 23, 0]
# Route 4: [0, 30, 2, 28, 22, 1, 42, 0]
# Route 5: [0, 27, 13, 15, 5, 37, 20, 19, 49, 0]
# Route 6: [0, 33, 16, 44, 32, 9, 0]
# Route 7: [0, 39, 10, 38, 11, 25, 0]
# Route 8: [0, 14, 31, 18, 24, 43, 0]
# Total distance: 868.62
# Execution time: 0.01 seconds
#
# Solving P-n050-k10.xml with Simulated Annealing
# Number of cities: 50
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 3, 0]
# Route 2: [0, 4, 34, 46, 8, 15, 0]
# Route 3: [0, 6, 2, 30, 48, 29, 0]
# Route 4: [0, 7, 35, 19, 14, 38, 49, 0]
# Route 5: [0, 45, 27, 13, 5, 37, 36, 0]
# Route 6: [0, 33, 1, 43, 41, 42, 23, 0]
# Route 7: [0, 16, 44, 32, 9, 0]
# Route 8: [0, 39, 10, 31, 25, 18, 0]
# Route 9: [0, 28, 21, 47, 20, 0]
# Route 10: [0, 11, 24, 22, 0]
# Total distance: 910.43
# Execution time: 0.01 seconds
#
# Solving P-n051-k10.xml with Simulated Annealing
# Number of cities: 51
# Number of vehicles: 10
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 46, 12, 47, 4, 17, 37, 0]
# Route 2: [0, 27, 1, 32, 11, 38, 9, 0]
# Route 3: [0, 6, 48, 8, 26, 31, 36, 0]
# Route 4: [0, 5, 49, 10, 30, 50, 29, 0]
# Route 5: [0, 18, 14, 24, 22, 0]
# Route 6: [0, 2, 16, 21, 34, 0]
# Route 7: [0, 23, 7, 43, 25, 0]
# Route 8: [0, 15, 44, 42, 19, 41, 0]
# Route 9: [0, 13, 40, 45, 33, 39, 0]
# Route 10: [0, 28, 3, 20, 35, 0]
# Total distance: 907.31
# Execution time: 0.01 seconds
#
# Solving P-n055-k07.xml with Simulated Annealing
# Number of cities: 55
# Number of vehicles: 7
# Vehicle capacity: 170.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 30, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 53, 14, 0]
# Route 3: [0, 45, 29, 48, 47, 21, 28, 22, 1, 23, 0]
# Route 4: [0, 52, 27, 13, 54, 19, 11, 38, 10, 0]
# Route 5: [0, 33, 16, 3, 44, 32, 9, 39, 25, 49, 0]
# Route 6: [0, 5, 37, 20, 15, 36, 43, 41, 42, 24, 18, 0]
# Route 7: [0, 50, 31, 0]
# Total distance: 761.08
# Execution time: 0.02 seconds
#
# Solving P-n055-k08.xml with Simulated Annealing
# Number of cities: 55
# Number of vehicles: 8
# Vehicle capacity: 160.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 2, 29, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 53, 19, 49, 0]
# Route 3: [0, 45, 27, 52, 13, 54, 14, 11, 23, 0]
# Route 4: [0, 30, 48, 47, 21, 28, 22, 1, 42, 0]
# Route 5: [0, 33, 16, 3, 44, 32, 9, 39, 18, 0]
# Route 6: [0, 5, 37, 20, 15, 36, 43, 41, 24, 50, 0]
# Route 7: [0, 10, 38, 31, 25, 0]
# Total distance: 873.43
# Execution time: 0.01 seconds
#
# Solving P-n055-k10.xml with Simulated Annealing
# Number of cities: 55
# Number of vehicles: 10
# Vehicle capacity: 115.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 3, 49, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 13, 0]
# Route 3: [0, 6, 2, 30, 48, 47, 15, 0]
# Route 4: [0, 7, 53, 14, 19, 54, 29, 0]
# Route 5: [0, 45, 27, 52, 5, 37, 20, 0]
# Route 6: [0, 33, 1, 43, 41, 42, 22, 23, 0]
# Route 7: [0, 16, 44, 32, 9, 39, 0]
# Route 8: [0, 28, 21, 36, 11, 0]
# Route 9: [0, 10, 38, 31, 25, 50, 0]
# Route 10: [0, 24, 18, 0]
# Total distance: 900.21
# Execution time: 0.01 seconds
#
# Solving P-n055-k15.xml with Simulated Annealing
# Number of cities: 55
# Number of vehicles: 15
# Vehicle capacity: 70.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 0]
# Route 2: [0, 4, 34, 52, 0]
# Route 3: [0, 17, 51, 6, 16, 0]
# Route 4: [0, 46, 8, 35, 7, 0]
# Route 5: [0, 45, 29, 48, 36, 0]
# Route 6: [0, 30, 2, 1, 0]
# Route 7: [0, 27, 13, 54, 19, 15, 0]
# Route 8: [0, 33, 43, 41, 23, 0]
# Route 9: [0, 3, 44, 32, 25, 0]
# Route 10: [0, 39, 9, 50, 0]
# Route 11: [0, 53, 14, 37, 0]
# Route 12: [0, 28, 21, 22, 0]
# Route 13: [0, 5, 47, 20, 49, 0]
# Route 14: [0, 10, 38, 18, 0]
# Route 15: [0, 11, 31, 0]
# Total distance: 1122.24
# Execution time: 0.01 seconds
#
# Solving P-n060-k10.xml with Simulated Annealing
# Number of cities: 60
# Number of vehicles: 10
# Vehicle capacity: 120.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 0]
# Route 3: [0, 45, 29, 48, 47, 21, 36, 23, 0]
# Route 4: [0, 52, 27, 13, 54, 19, 14, 0]
# Route 5: [0, 30, 2, 28, 22, 1, 42, 0]
# Route 6: [0, 33, 16, 3, 44, 32, 39, 0]
# Route 7: [0, 58, 10, 38, 11, 55, 49, 0]
# Route 8: [0, 53, 9, 25, 50, 18, 43, 0]
# Route 9: [0, 5, 15, 37, 20, 57, 59, 41, 0]
# Route 10: [0, 24, 56, 31, 0]
# Total distance: 1074.44
# Execution time: 0.01 seconds
#
# Solving P-n060-k15.xml with Simulated Annealing
# Number of cities: 60
# Number of vehicles: 15
# Vehicle capacity: 80.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 3, 0]
# Route 2: [0, 4, 34, 46, 0]
# Route 3: [0, 17, 51, 6, 2, 0]
# Route 4: [0, 7, 35, 8, 52, 27, 0]
# Route 5: [0, 45, 29, 48, 47, 23, 0]
# Route 6: [0, 30, 28, 21, 0]
# Route 7: [0, 33, 1, 43, 41, 0]
# Route 8: [0, 16, 49, 24, 18, 25, 0]
# Route 9: [0, 58, 10, 38, 55, 0]
# Route 10: [0, 44, 32, 9, 0]
# Route 11: [0, 39, 50, 31, 19, 0]
# Route 12: [0, 13, 54, 57, 15, 5, 0]
# Route 13: [0, 53, 14, 59, 0]
# Route 14: [0, 11, 37, 20, 0]
# Route 15: [0, 22, 42, 56, 36, 0]
# Total distance: 1226.11
# Execution time: 0.02 seconds
#
# Solving P-n065-k10.xml with Simulated Annealing
# Number of cities: 65
# Number of vehicles: 10
# Vehicle capacity: 130.0
#
# Solution routes:
# Route 1: [0, 26, 12, 40, 17, 51, 6, 63, 0]
# Route 2: [0, 4, 34, 46, 8, 35, 7, 13, 0]
# Route 3: [0, 45, 29, 48, 47, 21, 28, 0]
# Route 4: [0, 52, 27, 15, 57, 5, 37, 20, 60, 0]
# Route 5: [0, 30, 2, 62, 22, 1, 43, 41, 0]
# Route 6: [0, 33, 16, 3, 44, 32, 50, 49, 0]
# Route 7: [0, 58, 10, 38, 11, 53, 0]
# Route 8: [0, 39, 9, 25, 55, 18, 24, 23, 42, 0]
# Route 9: [0, 19, 54, 14, 59, 31, 36, 0]
# Route 10: [0, 61, 64, 56, 0]
# Total distance: 1054.03
# Execution time: 0.02 seconds
#
# Solving P-n070-k10.xml with Simulated Annealing
# Number of cities: 70
# Number of vehicles: 10
# Vehicle capacity: 135.0
#
# Solution routes:
# Route 1: [0, 67, 34, 46, 8, 35, 7, 26, 0]
# Route 2: [0, 4, 45, 29, 48, 47, 21, 0]
# Route 3: [0, 68, 6, 51, 17, 40, 12, 39, 55, 0]
# Route 4: [0, 52, 27, 13, 54, 19, 14, 53, 0]
# Route 5: [0, 30, 2, 62, 28, 22, 1, 23, 0]
# Route 6: [0, 33, 63, 16, 3, 44, 32, 50, 0]
# Route 7: [0, 58, 10, 38, 65, 11, 25, 0]
# Route 8: [0, 9, 18, 24, 49, 56, 41, 42, 69, 0]
# Route 9: [0, 5, 37, 20, 60, 36, 15, 57, 61, 0]
# Route 10: [0, 43, 64, 31, 66, 59, 0]
# Total distance: 1114.07
# Execution time: 0.02 seconds
#
# Solving P-n076-k04.xml with Simulated Annealing
# Number of cities: 76
# Number of vehicles: 4
# Vehicle capacity: 350.0
#
# Solution routes:
# Route 1: [0, 75, 68, 6, 51, 17, 40, 12, 26, 67, 34, 46, 8, 35, 7, 53, 14, 19, 54, 72, 0]
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 32, 9, 25, 0]
# Route 3: [0, 52, 27, 13, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 1, 43, 41, 42, 64, 56, 23, 49, 18, 55, 0]
# Route 4: [0, 30, 2, 24, 50, 39, 58, 10, 38, 65, 11, 66, 59, 31, 0]
# Total distance: 796.54
# Execution time: 0.02 seconds
#
# Solving P-n076-k05.xml with Simulated Annealing
# Number of cities: 76
# Number of vehicles: 5
# Vehicle capacity: 280.0
#
# Solution routes:
# Route 1: [0, 75, 68, 6, 51, 17, 40, 12, 26, 67, 34, 46, 8, 35, 7, 19, 0]
# Route 2: [0, 4, 45, 29, 48, 47, 21, 74, 28, 62, 73, 33, 63, 16, 3, 44, 72, 0]
# Route 3: [0, 52, 27, 13, 54, 57, 15, 5, 37, 20, 70, 60, 71, 36, 69, 61, 22, 1, 43, 41, 42, 0]
# Route 4: [0, 30, 2, 23, 56, 49, 24, 18, 50, 32, 9, 39, 58, 10, 65, 0]
# Route 5: [0, 53, 14, 11, 66, 38, 31, 25, 55, 59, 64, 0]
# Total distance: 890.85
# Execution time: 0.02 seconds
#
# Solving P-n101-k04.xml with Simulated Annealing
# Number of cities: 101
# Number of vehicles: 4
# Vehicle capacity: 400.0
#
# Solution routes:
# Route 1: [0, 53, 58, 40, 21, 73, 72, 74, 22, 75, 56, 39, 23, 67, 25, 55, 54, 80, 68, 77, 3, 79, 33, 81, 9, 35, 0]
# Route 2: [0, 27, 28, 26, 12, 76, 50, 1, 69, 31, 88, 7, 82, 48, 47, 36, 49, 19, 11, 62, 10, 90, 32, 63, 64, 30, 70, 0]
# Route 3: [0, 89, 6, 94, 95, 97, 92, 59, 99, 96, 93, 85, 91, 100, 37, 98, 61, 16, 44, 14, 42, 87, 2, 57, 15, 43, 38, 17, 84, 60, 83, 46, 78, 0]
# Route 4: [0, 13, 5, 18, 52, 8, 45, 86, 41, 4, 24, 29, 34, 71, 66, 20, 51, 65, 0]
# Total distance: 995.80
# Execution time: 0.03 seconds
