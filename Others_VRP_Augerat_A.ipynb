# %% [markdown]
# **This notebook has implementation and performance analysis of common algorithms for solving the vehicle routing problem on Augerat-1995 dataset set A.**

# %% [markdown]
# ---
#
#
# **Structure:**
#
# 1. Imports
# 2. Implementation:
#
# *   Neirest Neighbor
# *   LKH-3
# *   Simulated Annealing
#
# 3. Solution Routes
#
#
# ---

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import time
import glob
import os
import re
import random

from itertools import combinations
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# Load Data

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/DNA-Insipred NNs/Input/augerat-1995-set-a.zip'
# Out:
# Archive:  /content/drive/MyDrive/DNA-Insipred NNs/Input/augerat-1995-set-a.zip
# replace readme.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: readme.txt
#   inflating: A-n32-k05.xml
#   inflating: A-n33-k05.xml
#   inflating: A-n33-k06.xml
#   inflating: A-n34-k05.xml
#   inflating: A-n36-k05.xml
#   inflating: A-n37-k05.xml
#   inflating: A-n37-k06.xml
#   inflating: A-n38-k05.xml
#   inflating: A-n39-k05.xml
#   inflating: A-n39-k06.xml
#   inflating: A-n44-k06.xml
#   inflating: A-n45-k06.xml
#   inflating: A-n45-k07.xml
#   inflating: A-n46-k07.xml
#   inflating: A-n48-k07.xml
#   inflating: A-n53-k07.xml
#   inflating: A-n54-k07.xml
#   inflating: A-n55-k09.xml
#   inflating: A-n60-k09.xml
#   inflating: A-n61-k09.xml
#   inflating: A-n62-k08.xml
#   inflating: A-n63-k09.xml
#   inflating: A-n63-k10.xml
#   inflating: A-n64-k09.xml
#   inflating: A-n65-k09.xml
#   inflating: A-n69-k09.xml
#   inflating: A-n80-k10.xml

# %% [markdown]
# Implementation: Nearest Neighbor

# %%
def parse_xml_file(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Parse nodes
    nodes = []
    for node in root.findall('.//node'):
        node_id = int(node.get('id'))
        node_type = int(node.get('type'))
        cx = float(node.find('cx').text)
        cy = float(node.find('cy').text)
        nodes.append((node_id, node_type, cx, cy))

    # Parse vehicle capacity
    capacity = float(root.find('.//vehicle_profile/capacity').text)

    # Extract number of vehicles from filename
    filename = os.path.basename(file_path)
    match = re.search(r'-k(\d+)', filename)
    num_vehicles = int(match.group(1)) if match else len(root.findall('.//vehicle_profile'))

    # Parse demands
    demands = [0]  # Depot has no demand
    for request in root.findall('.//request'):
        demands.append(float(request.find('quantity').text))

    return nodes, capacity, num_vehicles, demands

def create_distance_matrix(nodes):
    coordinates = np.array([(x, y) for _, _, x, y in nodes])
    return squareform(pdist(coordinates))

def nearest_neighbor_vrp(num_cities, num_vehicles, capacity, demands):
    unvisited = set(range(1, num_cities))  # Skip depot (0)
    routes = []

    for _ in range(num_vehicles):
        if not unvisited:
            break

        current_route = []
        current_capacity = capacity
        current_city = 0  # Start from depot

        while unvisited:
            # Find nearest unvisited city that fits capacity
            nearest_city = None
            min_distance = float('inf')

            for city in unvisited:
                if demands[city] <= current_capacity:
                    distance = dist_matrix[current_city, city]
                    if distance < min_distance:
                        min_distance = distance
                        nearest_city = city

            if nearest_city is None:
                break

            current_route.append(nearest_city)
            current_capacity -= demands[nearest_city]
            current_city = nearest_city
            unvisited.remove(nearest_city)

        if current_route:
            routes.append(tuple(current_route))

    return routes

def calculate_route_distance(route):
    distance = dist_matrix[0, route[0]]  # Depot to first city
    for i in range(len(route)-1):
        distance += dist_matrix[route[i], route[i+1]]
    distance += dist_matrix[route[-1], 0]  # Last city to depot
    return distance

def solve_vrp(file_path):
    # Parse XML data
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)
    num_cities = len(nodes)

    # Create distance matrix
    global dist_matrix
    dist_matrix = create_distance_matrix(nodes)

    print(f"\nSolving {os.path.basename(file_path)}")
    print(f"Number of cities: {num_cities}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    # Start timer
    start_time = time.time()

    # Run nearest neighbor algorithm
    routes = nearest_neighbor_vrp(num_cities, num_vehicles, capacity, demands)

    # Print route details
    print("\nSolution routes:")
    total_distance = 0
    for i, route in enumerate(routes, 1):
        route_distance = calculate_route_distance(route)
        total_distance += route_distance
        print(f"Route {i}: {[0] + list(route) + [0]} (Distance: {route_distance:.2f})")
    print(f"Total distance: {total_distance:.2f}")

    # Print execution time
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")

def main():
    # Get all XML files
    xml_files = glob.glob('A-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving A-n32-k05.xml
# Number of cities: 32
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 30, 26, 16, 12, 1, 7, 14, 29, 22, 18, 0] (Distance: 262.33)
# Route 2: [0, 24, 27, 20, 5, 25, 10, 8, 0] (Distance: 262.01)
# Route 3: [0, 13, 21, 31, 19, 17, 3, 23, 0] (Distance: 212.99)
# Route 4: [0, 6, 2, 28, 4, 11, 9, 0] (Distance: 245.57)
# Route 5: [0, 15, 0] (Distance: 163.49)
# Total distance: 1146.40
# Execution time: 0.00 seconds
#
# Solving A-n33-k05.xml
# Number of cities: 33
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 22, 23, 28, 18, 11, 6, 24, 32, 0] (Distance: 149.41)
# Route 2: [0, 2, 20, 4, 12, 10, 30, 26, 1, 0] (Distance: 261.76)
# Route 3: [0, 15, 16, 3, 9, 17, 25, 0] (Distance: 181.04)
# Route 4: [0, 31, 21, 14, 19, 29, 27, 5, 0] (Distance: 235.32)
# Route 5: [0, 13, 8, 7, 0] (Distance: 150.62)
# Total distance: 978.15
# Execution time: 0.00 seconds
#
# Solving A-n33-k06.xml
# Number of cities: 33
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 28, 32, 10, 14, 17, 11, 31, 0] (Distance: 170.89)
# Route 2: [0, 25, 21, 16, 30, 27, 24, 0] (Distance: 186.23)
# Route 3: [0, 1, 18, 6, 7, 19, 5, 3, 0] (Distance: 155.37)
# Route 4: [0, 13, 8, 4, 22, 26, 23, 0] (Distance: 180.56)
# Route 5: [0, 12, 29, 20, 0] (Distance: 206.24)
# Route 6: [0, 2, 15, 9, 0] (Distance: 143.98)
# Total distance: 1043.27
# Execution time: 0.00 seconds
#
# Solving A-n34-k05.xml
# Number of cities: 34
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 20, 26, 4, 33, 18, 2, 16, 22, 0] (Distance: 197.27)
# Route 2: [0, 5, 30, 24, 27, 1, 29, 15, 0] (Distance: 137.24)
# Route 3: [0, 10, 13, 7, 6, 14, 8, 11, 31, 0] (Distance: 202.15)
# Route 4: [0, 21, 9, 12, 3, 32, 28, 0] (Distance: 232.46)
# Route 5: [0, 23, 19, 17, 25, 0] (Distance: 177.67)
# Total distance: 946.80
# Execution time: 0.00 seconds
#
# Solving A-n36-k05.xml
# Number of cities: 36
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 10, 7, 26, 20, 5, 1, 13, 0] (Distance: 209.48)
# Route 2: [0, 16, 11, 25, 27, 24, 21, 22, 32, 0] (Distance: 154.65)
# Route 3: [0, 9, 28, 14, 34, 23, 6, 3, 19, 33, 0] (Distance: 233.56)
# Route 4: [0, 15, 8, 35, 2, 12, 31, 4, 17, 0] (Distance: 349.37)
# Route 5: [0, 18, 30, 29, 0] (Distance: 156.44)
# Total distance: 1103.50
# Execution time: 0.00 seconds
#
# Solving A-n37-k05.xml
# Number of cities: 37
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 15, 21, 16, 7, 4, 33, 5, 13, 14, 0] (Distance: 189.67)
# Route 2: [0, 34, 36, 32, 28, 31, 26, 30, 35, 3, 9, 0] (Distance: 211.01)
# Route 3: [0, 1, 12, 17, 23, 20, 19, 2, 10, 0] (Distance: 164.40)
# Route 4: [0, 22, 6, 24, 8, 27, 11, 25, 18, 0] (Distance: 325.16)
# Route 5: [0, 29, 0] (Distance: 58.31)
# Total distance: 948.55
# Execution time: 0.00 seconds
#
# Solving A-n37-k06.xml
# Number of cities: 37
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 16, 7, 14, 18, 4, 17, 19, 1, 12, 0] (Distance: 278.89)
# Route 2: [0, 29, 36, 6, 20, 8, 5, 33, 28, 0] (Distance: 259.08)
# Route 3: [0, 34, 31, 26, 10, 11, 25, 0] (Distance: 185.98)
# Route 4: [0, 13, 30, 15, 32, 27, 0] (Distance: 171.58)
# Route 5: [0, 35, 22, 23, 0] (Distance: 238.79)
# Route 6: [0, 3, 9, 21, 2, 0] (Distance: 207.55)
# Total distance: 1341.88
# Execution time: 0.00 seconds
#
# Solving A-n38-k05.xml
# Number of cities: 38
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 14, 2, 13, 36, 17, 9, 21, 19, 12, 0] (Distance: 199.38)
# Route 2: [0, 32, 20, 7, 5, 22, 27, 31, 33, 0] (Distance: 213.35)
# Route 3: [0, 10, 30, 29, 34, 6, 25, 0] (Distance: 135.49)
# Route 4: [0, 18, 28, 37, 11, 16, 4, 1, 0] (Distance: 270.59)
# Route 5: [0, 8, 23, 35, 26, 3, 15, 0] (Distance: 265.80)
# Total distance: 1084.61
# Execution time: 0.00 seconds
#
# Solving A-n39-k05.xml
# Number of cities: 39
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 4, 18, 9, 12, 31, 0] (Distance: 76.05)
# Route 2: [0, 19, 33, 1, 20, 23, 29, 5, 16, 32, 3, 38, 8, 0] (Distance: 239.31)
# Route 3: [0, 21, 30, 13, 28, 6, 36, 27, 34, 0] (Distance: 225.32)
# Route 4: [0, 11, 17, 26, 24, 35, 2, 0] (Distance: 197.37)
# Route 5: [0, 25, 15, 10, 7, 22, 37, 0] (Distance: 294.53)
# Total distance: 1032.57
# Execution time: 0.00 seconds
#
# Solving A-n39-k06.xml
# Number of cities: 39
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 15, 13, 30, 5, 0] (Distance: 68.99)
# Route 2: [0, 24, 3, 38, 12, 37, 31, 14, 33, 23, 0] (Distance: 248.99)
# Route 3: [0, 26, 11, 6, 1, 36, 17, 21, 0] (Distance: 138.86)
# Route 4: [0, 29, 28, 9, 20, 32, 18, 22, 34, 27, 7, 0] (Distance: 257.59)
# Route 5: [0, 8, 2, 19, 4, 16, 35, 0] (Distance: 286.13)
# Route 6: [0, 10, 25, 0] (Distance: 212.35)
# Total distance: 1212.89
# Execution time: 0.00 seconds
#
# Solving A-n44-k06.xml
# Number of cities: 44
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 31, 8, 15, 28, 27, 19, 24, 0] (Distance: 106.50)
# Route 2: [0, 4, 34, 17, 12, 3, 6, 22, 9, 38, 21, 0] (Distance: 250.87)
# Route 3: [0, 2, 41, 14, 36, 25, 39, 0] (Distance: 136.12)
# Route 4: [0, 7, 5, 33, 10, 11, 26, 30, 40, 0] (Distance: 231.70)
# Route 5: [0, 29, 43, 23, 20, 16, 18, 0] (Distance: 274.66)
# Route 6: [0, 13, 1, 35, 37, 42, 32, 0] (Distance: 328.85)
# Total distance: 1328.69
# Execution time: 0.00 seconds
#
# Solving A-n45-k06.xml
# Number of cities: 45
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 9, 28, 7, 32, 13, 20, 10, 0] (Distance: 155.01)
# Route 2: [0, 14, 35, 1, 44, 6, 26, 11, 19, 2, 0] (Distance: 243.37)
# Route 3: [0, 38, 25, 12, 15, 22, 42, 4, 41, 0] (Distance: 262.32)
# Route 4: [0, 29, 43, 18, 17, 27, 5, 0] (Distance: 226.33)
# Route 5: [0, 31, 24, 37, 34, 40, 0] (Distance: 196.29)
# Route 6: [0, 3, 8, 33, 21, 16, 36, 39, 0] (Distance: 262.27)
# Total distance: 1345.59
# Execution time: 0.00 seconds
#
# Solving A-n45-k07.xml
# Number of cities: 45
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 35, 39, 34, 26, 4, 6, 21, 2, 8, 38, 0] (Distance: 174.62)
# Route 2: [0, 12, 32, 13, 18, 7, 16, 20, 40, 0] (Distance: 147.27)
# Route 3: [0, 9, 10, 15, 25, 23, 42, 14, 0] (Distance: 198.13)
# Route 4: [0, 24, 44, 33, 31, 5, 0] (Distance: 186.52)
# Route 5: [0, 28, 3, 11, 43, 41, 27, 0] (Distance: 218.44)
# Route 6: [0, 17, 22, 30, 19, 0] (Distance: 224.02)
# Route 7: [0, 29, 36, 37, 1, 0] (Distance: 255.04)
# Total distance: 1404.05
# Execution time: 0.00 seconds
#
# Solving A-n46-k07.xml
# Number of cities: 46
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 9, 28, 17, 21, 41, 20, 27, 1, 33, 36, 0] (Distance: 212.97)
# Route 2: [0, 38, 14, 43, 6, 26, 13, 30, 5, 3, 45, 0] (Distance: 189.54)
# Route 3: [0, 32, 22, 39, 7, 10, 18, 0] (Distance: 189.98)
# Route 4: [0, 4, 2, 37, 44, 11, 0] (Distance: 197.18)
# Route 5: [0, 19, 8, 15, 16, 24, 42, 0] (Distance: 153.81)
# Route 6: [0, 12, 35, 25, 40, 34, 31, 0] (Distance: 264.75)
# Route 7: [0, 29, 0] (Distance: 127.56)
# Total distance: 1335.79
# Execution time: 0.00 seconds
#
# Solving A-n48-k07.xml
# Number of cities: 48
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 17, 18, 44, 35, 23, 43, 31, 32, 0] (Distance: 145.91)
# Route 2: [0, 41, 47, 16, 10, 2, 29, 34, 0] (Distance: 219.53)
# Route 3: [0, 12, 5, 1, 6, 22, 7, 42, 0] (Distance: 248.31)
# Route 4: [0, 40, 36, 37, 19, 38, 25, 0] (Distance: 169.95)
# Route 5: [0, 45, 27, 15, 8, 39, 26, 3, 0] (Distance: 203.28)
# Route 6: [0, 28, 9, 24, 4, 13, 30, 21, 46, 11, 0] (Distance: 257.67)
# Route 7: [0, 33, 20, 0] (Distance: 231.94)
# Total distance: 1476.57
# Execution time: 0.00 seconds
#
# Solving A-n53-k07.xml
# Number of cities: 53
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 1, 4, 28, 22, 30, 44, 46, 8, 27, 29, 25, 0] (Distance: 208.48)
# Route 2: [0, 31, 20, 6, 35, 38, 18, 51, 39, 0] (Distance: 166.20)
# Route 3: [0, 33, 3, 5, 14, 34, 7, 0] (Distance: 180.21)
# Route 4: [0, 47, 9, 17, 41, 11, 24, 52, 0] (Distance: 138.28)
# Route 5: [0, 12, 45, 2, 37, 36, 50, 43, 23, 19, 15, 49, 0] (Distance: 279.67)
# Route 6: [0, 21, 13, 16, 32, 48, 40, 0] (Distance: 269.24)
# Route 7: [0, 10, 26, 42, 0] (Distance: 207.46)
# Total distance: 1449.54
# Execution time: 0.00 seconds
#
# Solving A-n54-k07.xml
# Number of cities: 54
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 43, 4, 28, 5, 7, 39, 50, 20, 23, 0] (Distance: 95.19)
# Route 2: [0, 52, 30, 16, 6, 32, 13, 11, 38, 26, 35, 0] (Distance: 198.63)
# Route 3: [0, 18, 49, 29, 15, 10, 1, 36, 17, 45, 0] (Distance: 200.96)
# Route 4: [0, 34, 41, 46, 51, 42, 24, 2, 12, 27, 14, 0] (Distance: 181.29)
# Route 5: [0, 25, 47, 37, 8, 19, 31, 33, 0] (Distance: 283.64)
# Route 6: [0, 44, 53, 3, 22, 0] (Distance: 190.34)
# Route 7: [0, 9, 21, 40, 48, 0] (Distance: 283.59)
# Total distance: 1433.64
# Execution time: 0.00 seconds
#
# Solving A-n55-k09.xml
# Number of cities: 55
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 36, 8, 21, 12, 32, 10, 5, 40, 0] (Distance: 133.88)
# Route 2: [0, 25, 41, 29, 18, 48, 50, 44, 0] (Distance: 138.31)
# Route 3: [0, 4, 7, 42, 31, 26, 46, 14, 16, 0] (Distance: 193.59)
# Route 4: [0, 37, 3, 17, 34, 33, 20, 0] (Distance: 89.05)
# Route 5: [0, 30, 22, 19, 27, 13, 28, 54, 0] (Distance: 136.50)
# Route 6: [0, 53, 38, 47, 39, 9, 35, 1, 0] (Distance: 198.20)
# Route 7: [0, 2, 51, 11, 15, 43, 52, 0] (Distance: 270.10)
# Route 8: [0, 6, 45, 0] (Distance: 113.56)
# Route 9: [0, 23, 24, 49, 0] (Distance: 226.13)
# Total distance: 1499.31
# Execution time: 0.00 seconds
#
# Solving A-n60-k09.xml
# Number of cities: 60
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0,
# Route 6: [0, 54, 33, 1, 12, 13, 24, 59, 0] (Distance: 191.81)
# Route 7: [0, 30, 37, 60, 50, 16, 41, 0] (Distance: 143.31)
# Route 8: [0, 53, 44, 56, 8, 38, 0] (Distance: 210.79)
# Route 9: [0, 20, 58, 40, 2, 0] (Distance: 211.50)
# Total distance: 1802.41
# Execution time: 0.00 seconds
#
# Solving A-n69-k09.xml
# Number of cities: 69
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 19, 24, 43, 52, 26, 54, 5, 46, 0] (Distance: 100.55)
# Route 2: [0, 28, 34, 14, 42, 57, 11, 63, 37, 16, 1, 10, 0] (Distance: 188.40)
# Route 3: [0, 7, 27, 65, 55, 60, 4, 47, 25, 29, 2, 0] (Distance: 238.06)
# Route 4: [0, 31, 18, 53, 9, 30, 51, 3, 15, 44, 6, 0] (Distance: 155.23)
# Route 5: [0, 58, 22, 12, 66, 23, 41, 0] (Distance: 161.06)
# Route 6: [0, 67, 64, 61, 21, 33, 49, 13, 20, 40, 0] (Distance: 282.56)
# Route 7: [0, 62, 56, 39, 8, 59, 0] (Distance: 144.69)
# Route 8: [0, 50, 48, 36, 17, 32, 0] (Distance: 139.29)
# Route 9: [0, 68, 38, 35, 45, 0] (Distance: 167.03)
# Total distance: 1576.88
# Execution time: 0.00 seconds
#
# Solving A-n80-k10.xml
# Number of cities: 80
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 49, 73, 36, 42, 51, 77, 3, 29, 31, 0] (Distance: 157.42)
# Route 2: [0, 40, 21, 1, 7, 10, 71, 14, 33, 0] (Distance: 245.26)
# Route 3: [0, 13, 53, 66, 67, 70, 38, 58, 50, 76, 0] (Distance: 168.26)
# Route 4: [0, 74, 60, 39, 17, 27, 59, 0] (Distance: 161.43)
# Route 5: [0, 62, 23, 44, 12, 5, 30, 6, 0] (Distance: 171.93)
# Route 6: [0, 63, 11, 34, 24, 2, 37, 8, 68, 0] (Distance: 223.80)
# Route 7: [0, 72, 45, 22, 32, 4, 54, 9, 15, 64, 47, 0] (Distance: 339.50)
# Route 8: [0, 52, 28, 79, 48, 18, 78, 20, 0] (Distance: 253.18)
# Route 9: [0, 46, 25, 41, 55, 56, 69, 65, 35, 26, 19, 75, 16, 0] (Distance: 310.71)
# Route 10: [0, 61, 57, 43, 0] (Distance: 223.96)
# Total distance: 2255.46
# Execution time: 0.00 seconds

# %% [markdown]
# Implementation: LKH-3

# %%
class LKH_VRP:
    def __init__(self, dist_matrix, num_vehicles, capacity, demands):
        self.dist_matrix = dist_matrix
        self.num_cities = len(dist_matrix)
        self.num_vehicles = num_vehicles
        self.capacity = capacity
        self.demands = demands

    def initial_solution(self):
        unvisited = set(range(1, self.num_cities))
        routes = []

        for _ in range(self.num_vehicles):
            if not unvisited:
                break

            current_route = []
            current_capacity = self.capacity
            current_city = 0

            while unvisited:
                nearest_city = None
                min_distance = float('inf')

                for city in unvisited:
                    if self.demands[city] <= current_capacity:
                        distance = self.dist_matrix[current_city][city]
                        if distance < min_distance:
                            min_distance = distance
                            nearest_city = city

                if nearest_city is None:
                    break

                current_route.append(nearest_city)
                current_capacity -= self.demands[nearest_city]
                current_city = nearest_city
                unvisited.remove(nearest_city)

            if current_route:
                routes.append(current_route)

        return routes

    def calculate_route_length(self, route):
        length = self.dist_matrix[0][route[0]]
        for i in range(len(route) - 1):
            length += self.dist_matrix[route[i]][route[i + 1]]
        length += self.dist_matrix[route[-1]][0]
        return length

    def calculate_total_distance(self, routes):
        return sum(self.calculate_route_length(route) for route in routes)

    def is_feasible_route(self, route):
        return sum(self.demands[i] for i in route) <= self.capacity

    def two_opt_move(self, route, i, j):
        new_route = route[:i] + route[i:j+1][::-1] + route[j+1:]
        return new_route

    def three_opt_move(self, route):
        if len(route) < 3:
            return route

        best_route = route
        best_length = self.calculate_route_length(route)

        for i, j, k in combinations(range(len(route)), 3):
            if j <= i + 1 or k <= j + 1:
                continue

            # Try all possible 3-opt combinations
            segments = [route[:i+1], route[i+1:j+1], route[j+1:k+1], route[k+1:]]
            for flip1 in [False, True]:
                for flip2 in [False, True]:
                    for flip3 in [False, True]:
                        if flip1:
                            segments[1] = segments[1][::-1]
                        if flip2:
                            segments[2] = segments[2][::-1]
                        if flip3:
                            segments[3] = segments[3][::-1]

                        new_route = segments[0] + segments[1] + segments[2] + segments[3]
                        new_length = self.calculate_route_length(new_route)

                        if new_length < best_length and self.is_feasible_route(new_route):
                            best_route = new_route
                            best_length = new_length

        return best_route

    def optimize_route(self, route):
        improved = True
        best_route = route

        while improved:
            improved = False
            current_length = self.calculate_route_length(best_route)

            # Apply 2-opt
            for i in range(len(route) - 1):
                for j in range(i + 1, len(route)):
                    new_route = self.two_opt_move(best_route, i, j)
                    if (self.calculate_route_length(new_route) < current_length and
                        self.is_feasible_route(new_route)):
                        best_route = new_route
                        improved = True
                        break
                if improved:
                    break

            # Apply 3-opt
            if not improved:
                new_route = self.three_opt_move(best_route)
                if (self.calculate_route_length(new_route) < current_length and
                    self.is_feasible_route(new_route)):
                    best_route = new_route
                    improved = True

        return best_route

    def solve(self, max_iterations=100):
        best_solution = self.initial_solution()
        best_distance = self.calculate_total_distance(best_solution)

        for _ in range(max_iterations):
            current_solution = [self.optimize_route(route) for route in best_solution]
            current_distance = self.calculate_total_distance(current_solution)

            if current_distance < best_distance:
                best_solution = current_solution
                best_distance = current_distance

        return best_solution, best_distance

def solve_vrp_lkh(file_path):
    # Parse XML data
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)

    print(f"\nSolving {os.path.basename(file_path)} with LKH")
    print(f"Number of cities: {len(nodes)}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    # Create distance matrix
    dist_matrix = create_distance_matrix(nodes)

    # Start timer
    start_time = time.time()

    # Create and run LKH solver
    solver = LKH_VRP(dist_matrix, num_vehicles, capacity, demands)
    routes, total_distance = solver.solve()

    # Print route details
    print("\nSolution routes:")
    for i, route in enumerate(routes, 1):
        route_distance = solver.calculate_route_length(route)
        print(f"Route {i}: {[0] + list(route) + [0]} (Distance: {route_distance:.2f})")
    print(f"Total distance: {total_distance:.2f}")

    # Print execution time
    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")

def main():
    # Get all XML files
    xml_files = glob.glob('A-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp_lkh(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving A-n32-k05.xml with LKH
# Number of cities: 32
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 30, 26, 16, 12, 1, 7, 18, 22, 29, 14, 0] (Distance: 247.40)
# Route 2: [0, 20, 5, 25, 10, 8, 24, 27, 0] (Distance: 248.81)
# Route 3: [0, 13, 21, 31, 19, 17, 3, 23, 0] (Distance: 212.99)
# Route 4: [0, 6, 2, 28, 4, 11, 9, 0] (Distance: 245.57)
# Route 5: [0, 15, 0] (Distance: 163.49)
# Total distance: 1118.26
# Execution time: 0.26 seconds
#
# Solving A-n33-k05.xml with LKH
# Number of cities: 33
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 22, 23, 28, 18, 11, 6, 24, 32, 0] (Distance: 149.41)
# Route 2: [0, 2, 20, 26, 30, 10, 12, 4, 1, 0] (Distance: 254.72)
# Route 3: [0, 15, 16, 3, 9, 17, 25, 0] (Distance: 181.04)
# Route 4: [0, 5, 27, 29, 31, 21, 14, 19, 0] (Distance: 221.01)
# Route 5: [0, 13, 8, 7, 0] (Distance: 150.62)
# Total distance: 956.79
# Execution time: 0.16 seconds
#
# Solving A-n33-k06.xml with LKH
# Number of cities: 33
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 17, 11, 10, 32, 28, 31, 0] (Distance: 153.39)
# Route 2: [0, 21, 25, 16, 30, 27, 24, 0] (Distance: 178.69)
# Route 3: [0, 1, 18, 6, 7, 19, 3, 5, 0] (Distance: 143.70)
# Route 4: [0, 13, 8, 4, 22, 26, 23, 0] (Distance: 180.56)
# Route 5: [0, 12, 29, 20, 0] (Distance: 206.24)
# Route 6: [0, 2, 9, 15, 0] (Distance: 143.83)
# Total distance: 1006.41
# Execution time: 0.09 seconds
#
# Solving A-n34-k05.xml with LKH
# Number of cities: 34
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 20, 18, 2, 22, 16, 33, 4, 26, 0] (Distance: 170.18)
# Route 2: [0, 5, 30, 24, 27, 1, 29, 15, 0] (Distance: 137.24)
# Route 3: [0, 10, 13, 31, 11, 8, 6, 7, 14, 0] (Distance: 172.45)
# Route 4: [0, 21, 28, 32, 3, 12, 9, 0] (Distance: 230.03)
# Route 5: [0, 23, 19, 17, 25, 0] (Distance: 177.67)
# Total distance: 887.57
# Execution time: 0.16 seconds
#
# Solving A-n36-k05.xml with LKH
# Number of cities: 36
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 10, 7, 26, 20, 5, 13, 1, 0] (Distance: 199.08)
# Route 2: [0, 11, 25, 27, 21, 32, 22, 24, 16, 0] (Distance: 148.32)
# Route 3: [0, 33, 19, 3, 6, 23, 34, 14, 28, 9, 0] (Distance: 233.56)
# Route 4: [0, 15, 8, 35, 2, 4, 31, 12, 17, 0] (Distance: 340.42)
# Route 5: [0, 18, 30, 29, 0] (Distance: 156.44)
# Total distance: 1077.82
# Execution time: 0.26 seconds
#
# Solving A-n37-k05.xml with LKH
# Number of cities: 37
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 21, 16, 7, 4, 33, 5, 13, 14, 15, 0] (Distance: 188.26)
# Route 2: [0, 3, 9, 35, 30, 26, 31, 28, 32, 36, 34, 0] (Distance: 193.23)
# Route 3: [0, 1, 12, 10, 2, 19, 20, 23, 17, 0] (Distance: 154.64)
# Route 4: [0, 18, 25, 8, 27, 11, 24, 6, 22, 0] (Distance: 310.48)
# Route 5: [0, 29, 0] (Distance: 58.31)
# Total distance: 904.92
# Execution time: 0.41 seconds
#
# Solving A-n37-k06.xml with LKH
# Number of cities: 37
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 16, 7, 12, 1, 19, 17, 4, 18, 14, 0] (Distance: 260.41)
# Route 2: [0, 28, 33, 5, 8, 20, 6, 36, 29, 0] (Distance: 259.08)
# Route 3: [0, 34, 31, 26, 10, 11, 25, 0] (Distance: 185.98)
# Route 4: [0, 13, 30, 15, 32, 27, 0] (Distance: 171.58)
# Route 5: [0, 35, 22, 23, 0] (Distance: 238.79)
# Route 6: [0, 21, 2, 9, 3, 0] (Distance: 199.94)
# Total distance: 1315.79
# Execution time: 0.26 seconds
#
# Solving A-n38-k05.xml with LKH
# Number of cities: 38
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 14, 2, 13, 36, 17, 9, 21, 12, 19, 0] (Distance: 189.71)
# Route 2: [0, 32, 20, 7, 5, 22, 27, 31, 33, 0] (Distance: 213.35)
# Route 3: [0, 10, 30, 29, 25, 6, 34, 0] (Distance: 134.60)
# Route 4: [0, 11, 37, 28, 16, 4, 1, 18, 0] (Distance: 254.14)
# Route 5: [0, 26, 3, 23, 35, 8, 15, 0] (Distance: 242.99)
# Total distance: 1034.81
# Execution time: 0.29 seconds
#
# Solving A-n39-k05.xml with LKH
# Number of cities: 39
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 12, 31, 9, 18, 4, 0] (Distance: 74.21)
# Route 2: [0, 8, 38, 32, 3, 16, 5, 29, 1, 20, 23, 33, 19, 0] (Distance: 225.38)
# Route 3: [0, 21, 30, 13, 28, 6, 36, 27, 34, 0] (Distance: 225.32)
# Route 4: [0, 17, 2, 35, 24, 26, 11, 0] (Distance: 193.85)
# Route 5: [0, 25, 15, 10, 7, 22, 37, 0] (Distance: 294.53)
# Total distance: 1013.28
# Execution time: 0.53 seconds
#
# Solving A-n39-k06.xml with LKH
# Number of cities: 39
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 13, 30, 15, 5, 0] (Distance: 67.74)
# Route 2: [0, 24, 3, 12, 38, 37, 31, 14, 33, 23, 0] (Distance: 248.05)
# Route 3: [0, 26, 11, 6, 1, 36, 17, 21, 0] (Distance: 138.86)
# Route 4: [0, 9, 28, 29, 7, 27, 34, 22, 18, 32, 20, 0] (Distance: 250.87)
# Route 5: [0, 8, 16, 4, 19, 2, 35, 0] (Distance: 270.34)
# Route 6: [0, 10, 25, 0] (Distance: 212.35)
# Total distance: 1188.20
# Execution time: 0.34 seconds
#
# Solving A-n44-k06.xml with LKH
# Number of cities: 44
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 8, 15, 28, 27, 24, 19, 31, 0] (Distance: 93.98)
# Route 2: [0, 38, 9, 22, 6, 3, 12, 17, 34, 21, 4, 0] (Distance: 221.50)
# Route 3: [0, 39, 25, 36, 14, 41, 2, 0] (Distance: 136.12)
# Route 4: [0, 40, 30, 26, 11, 10, 33, 5, 7, 0] (Distance: 231.70)
# Route 5: [0, 23, 20, 16, 18, 43, 29, 0] (Distance: 255.31)
# Route 6: [0, 32, 37, 42, 1, 35, 13, 0] (Distance: 323.98)
# Total distance: 1262.60
# Execution time: 0.31 seconds
#
# Solving A-n45-k06.xml with LKH
# Number of cities: 45
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 28, 7, 32, 13, 20, 10, 9, 23, 0] (Distance: 148.13)
# Route 2: [0, 26, 11, 19, 6, 44, 1, 35, 14, 2, 0] (Distance: 215.76)
# Route 3: [0, 41, 4, 42, 22, 15, 12, 25, 38, 0] (Distance: 262.32)
# Route 4: [0, 5, 17, 18, 43, 27, 29, 0] (Distance: 195.83)
# Route 5: [0, 31, 24, 37, 34, 40, 0] (Distance: 196.29)
# Route 6: [0, 3, 21, 33, 8, 16, 36, 39, 0] (Distance: 258.91)
# Total distance: 1277.24
# Execution time: 0.28 seconds
#
# Solving A-n45-k07.xml with LKH
# Number of cities: 45
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 2, 6, 4, 26, 34, 21, 8, 38, 35, 39, 0] (Distance: 154.33)
# Route 2: [0, 40, 20, 16, 7, 18, 13, 32, 12, 0] (Distance: 147.27)
# Route 3: [0, 14, 10, 15, 42, 23, 25, 9, 0] (Distance: 191.84)
# Route 4: [0, 24, 44, 33, 31, 5, 0] (Distance: 186.52)
# Route 5: [0, 27, 41, 43, 11, 3, 28, 0] (Distance: 218.44)
# Route 6: [0, 19, 30, 22, 17, 0] (Distance: 224.02)
# Route 7: [0, 29, 36, 37, 1, 0] (Distance: 255.04)
# Total distance: 1377.47
# Execution time: 0.29 seconds
#
# Solving A-n46-k07.xml with LKH
# Number of cities: 46
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 9, 28, 17, 21, 41, 20, 27, 1, 33, 36, 0] (Distance: 212.97)
# Route 2: [0, 5, 3, 30, 13, 26, 38, 14, 43, 6, 45, 0] (Distance: 164.22)
# Route 3: [0, 39, 18, 10, 7, 22, 32, 0] (Distance: 184.14)
# Route 4: [0, 11, 44, 37, 2, 4, 0] (Distance: 197.18)
# Route 5: [0, 19, 15, 24, 16, 42, 8, 0] (Distance: 145.97)
# Route 6: [0, 25, 35, 12, 40, 34, 31, 0] (Distance: 261.54)
# Route 7: [0, 29, 0] (Distance: 127.56)
# Total distance: 1293.58
# Execution time: 0.51 seconds
#
# Solving A-n48-k07.xml with LKH
# Number of cities: 48
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 31, 43, 32, 35, 44, 18, 17, 14, 0] (Distance: 134.33)
# Route 2: [0, 34, 29, 10, 2, 47, 16, 41, 0] (Distance: 211.40)
# Route 3: [0, 12, 5, 1, 6, 22, 7, 42, 0] (Distance: 248.31)
# Route 4: [0, 40, 36, 37, 19, 25, 38, 0] (Distance: 164.38)
# Route 5: [0, 45, 27, 15, 8, 39, 26, 3, 0] (Distance: 203.28)
# Route 6: [0, 28, 21, 30, 46, 13, 11, 4, 24, 9, 0] (Distance: 228.37)
# Route 7: [0, 33, 20, 0] (Distance: 231.94)
# Total distance: 1422.01
# Execution time: 0.32 seconds
#
# Solving A-n53-k07.xml with LKH
# Number of cities: 53
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0,
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 19, 24, 43, 52, 5, 46, 54, 26, 0] (Distance: 97.24)
# Route 2: [0, 16, 1, 10, 37, 63, 11, 57, 42, 14, 34, 28, 0] (Distance: 177.99)
# Route 3: [0, 29, 25, 47, 4, 60, 55, 65, 27, 7, 2, 0] (Distance: 225.50)
# Route 4: [0, 31, 18, 53, 9, 30, 6, 15, 44, 3, 51, 0] (Distance: 150.15)
# Route 5: [0, 58, 22, 12, 41, 66, 23, 0] (Distance: 143.20)
# Route 6: [0, 40, 20, 13, 49, 33, 64, 61, 21, 67, 0] (Distance: 270.36)
# Route 7: [0, 62, 56, 39, 8, 59, 0] (Distance: 144.69)
# Route 8: [0, 48, 36, 17, 32, 50, 0] (Distance: 137.48)
# Route 9: [0, 38, 68, 45, 35, 0] (Distance: 158.03)
# Total distance: 1504.64
# Execution time: 0.82 seconds
#
# Solving A-n80-k10.xml with LKH
# Number of cities: 80
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 49, 73, 36, 77, 3, 31, 29, 51, 42, 0] (Distance: 152.03)
# Route 2: [0, 40, 21, 1, 7, 10, 14, 71, 33, 0] (Distance: 244.58)
# Route 3: [0, 13, 53, 70, 76, 50, 58, 38, 67, 66, 0] (Distance: 160.39)
# Route 4: [0, 74, 59, 27, 17, 60, 39, 0] (Distance: 156.52)
# Route 5: [0, 62, 23, 6, 30, 5, 44, 12, 0] (Distance: 158.25)
# Route 6: [0, 24, 68, 8, 37, 2, 34, 11, 63, 0] (Distance: 216.89)
# Route 7: [0, 72, 32, 4, 22, 45, 54, 9, 47, 15, 64, 0] (Distance: 302.07)
# Route 8: [0, 52, 28, 79, 48, 18, 78, 20, 0] (Distance: 253.18)
# Route 9: [0, 16, 75, 19, 26, 35, 65, 69, 56, 55, 41, 25, 46, 0] (Distance: 310.71)
# Route 10: [0, 57, 43, 61, 0] (Distance: 221.55)
# Total distance: 2176.16
# Execution time: 1.01 seconds

# %% [markdown]
# Implementation: Simulated Annealing

# %%
class SimulatedAnnealingVRP:
    def __init__(self, dist_matrix, num_vehicles, capacity, demands):
        self.dist_matrix = dist_matrix
        self.num_cities = len(dist_matrix)
        self.num_vehicles = num_vehicles
        self.capacity = capacity
        self.demands = demands

    def initial_solution(self):
        unvisited = set(range(1, self.num_cities))
        routes = []

        for _ in range(self.num_vehicles):
            if not unvisited:
                break

            current_route = []
            current_capacity = self.capacity
            current_city = 0

            while unvisited:
                nearest_city = None
                min_distance = float('inf')

                for city in unvisited:
                    if self.demands[city] <= current_capacity:
                        distance = self.dist_matrix[current_city][city]
                        if distance < min_distance:
                            min_distance = distance
                            nearest_city = city

                if nearest_city is None:
                    break

                current_route.append(nearest_city)
                current_capacity -= self.demands[nearest_city]
                current_city = nearest_city
                unvisited.remove(nearest_city)

            if current_route:
                routes.append(current_route)

        return routes

    def calculate_total_distance(self, routes):
        total_distance = 0
        for route in routes:
            if not route:  # Skip empty routes
                continue
            route_distance = self.dist_matrix[0][route[0]]
            for i in range(len(route) - 1):
                route_distance += self.dist_matrix[route[i]][route[i + 1]]
            route_distance += self.dist_matrix[route[-1]][0]
            total_distance += route_distance
        return total_distance

    def is_feasible(self, routes):
        for route in routes:
            if sum(self.demands[i] for i in route) > self.capacity:
                return False
        return True

    def generate_neighbor(self, routes):
        neighbor_routes = [list(route) for route in routes]

        if not neighbor_routes:
            return neighbor_routes

        r1 = random.randint(0, len(neighbor_routes) - 1)
        r2 = random.randint(0, len(neighbor_routes) - 1)

        if len(neighbor_routes[r1]) > 0:
            i = random.randint(0, len(neighbor_routes[r1])-1)
            if len(neighbor_routes[r2]) > 0:
                j = random.randint(0, len(neighbor_routes[r2])-1)
                if r1 == r2:
                    neighbor_routes[r1][i], neighbor_routes[r2][j] = neighbor_routes[r2][j], neighbor_routes[r1][i]
                else:
                    city = neighbor_routes[r1].pop(i)
                    neighbor_routes[r2].insert(j, city)

        neighbor_routes = [route for route in neighbor_routes if route]
        return neighbor_routes

    def solve(self, initial_temperature=1000, cooling_rate=0.99, max_iterations=1000):
        current_solution = self.initial_solution()
        current_cost = self.calculate_total_distance(current_solution)
        best_solution = current_solution.copy()
        best_cost = current_cost
        temperature = initial_temperature

        for _ in range(max_iterations):
            neighbor = self.generate_neighbor(current_solution)

            if neighbor and self.is_feasible(neighbor):
                neighbor_cost = self.calculate_total_distance(neighbor)
                cost_diff = neighbor_cost - current_cost

                if cost_diff < 0 or random.random() < np.exp(-cost_diff / temperature):
                    current_solution = neighbor
                    current_cost = neighbor_cost

                    if current_cost < best_cost:
                        best_solution = current_solution.copy()
                        best_cost = current_cost

            temperature *= cooling_rate
            if temperature < 0.1:
                break

        return best_solution, best_cost

def solve_vrp_sa(file_path):
    nodes, capacity, num_vehicles, demands = parse_xml_file(file_path)

    print(f"\nSolving {os.path.basename(file_path)} with Simulated Annealing")
    print(f"Number of cities: {len(nodes)}")
    print(f"Number of vehicles: {num_vehicles}")
    print(f"Vehicle capacity: {capacity}")

    dist_matrix = create_distance_matrix(nodes)

    start_time = time.time()

    solver = SimulatedAnnealingVRP(dist_matrix, num_vehicles, capacity, demands)
    routes, total_distance = solver.solve()

    print("\nSolution routes:")
    for i, route in enumerate(routes, 1):
        print(f"Route {i}: {[0] + route + [0]}")
    print(f"Total distance: {total_distance:.2f}")

    execution_time = time.time() - start_time
    print(f"Execution time: {execution_time:.2f} seconds")

def main():
    xml_files = glob.glob('A-n*.xml')

    for file_path in sorted(xml_files):
        solve_vrp_sa(file_path)

if __name__ == "__main__":
    main()
# Out:
# Solving A-n32-k05.xml with Simulated Annealing
# Number of cities: 32
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 30, 26, 16, 12, 1, 7, 14, 29, 22, 18, 0]
# Route 2: [0, 24, 27, 20, 5, 25, 10, 8, 0]
# Route 3: [0, 13, 21, 31, 19, 17, 3, 23, 0]
# Route 4: [0, 6, 2, 28, 4, 11, 9, 0]
# Route 5: [0, 15, 0]
# Total distance: 1146.40
# Execution time: 0.02 seconds
#
# Solving A-n33-k05.xml with Simulated Annealing
# Number of cities: 33
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 22, 23, 28, 18, 11, 6, 24, 32, 0]
# Route 2: [0, 2, 20, 4, 12, 10, 30, 26, 1, 0]
# Route 3: [0, 15, 16, 3, 9, 17, 25, 0]
# Route 4: [0, 31, 21, 14, 19, 29, 27, 5, 0]
# Route 5: [0, 13, 8, 7, 0]
# Total distance: 978.15
# Execution time: 0.01 seconds
#
# Solving A-n33-k06.xml with Simulated Annealing
# Number of cities: 33
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 28, 32, 10, 14, 17, 11, 31, 0]
# Route 2: [0, 25, 21, 16, 30, 27, 24, 0]
# Route 3: [0, 1, 18, 6, 7, 19, 5, 3, 0]
# Route 4: [0, 13, 8, 4, 22, 26, 23, 0]
# Route 5: [0, 12, 29, 20, 0]
# Route 6: [0, 2, 15, 9, 0]
# Total distance: 1043.27
# Execution time: 0.01 seconds
#
# Solving A-n34-k05.xml with Simulated Annealing
# Number of cities: 34
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 20, 26, 4, 33, 18, 2, 16, 22, 0]
# Route 2: [0, 5, 30, 24, 27, 1, 29, 15, 0]
# Route 3: [0, 10, 13, 7, 6, 14, 8, 11, 31, 0]
# Route 4: [0, 21, 9, 12, 3, 32, 28, 0]
# Route 5: [0, 23, 19, 17, 25, 0]
# Total distance: 946.80
# Execution time: 0.01 seconds
#
# Solving A-n36-k05.xml with Simulated Annealing
# Number of cities: 36
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 10, 7, 26, 20, 5, 1, 13, 0]
# Route 2: [0, 16, 11, 25, 27, 24, 21, 22, 32, 0]
# Route 3: [0, 9, 28, 14, 34, 23, 6, 3, 19, 33, 0]
# Route 4: [0, 15, 8, 35, 2, 12, 31, 4, 17, 0]
# Route 5: [0, 18, 30, 29, 0]
# Total distance: 1103.50
# Execution time: 0.01 seconds
#
# Solving A-n37-k05.xml with Simulated Annealing
# Number of cities: 37
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 15, 21, 16, 7, 4, 33, 5, 13, 14, 0]
# Route 2: [0, 34, 36, 32, 28, 31, 26, 30, 35, 3, 9, 0]
# Route 3: [0, 1, 12, 17, 23, 20, 19, 2, 10, 0]
# Route 4: [0, 22, 6, 24, 8, 27, 11, 25, 18, 0]
# Route 5: [0, 29, 0]
# Total distance: 948.55
# Execution time: 0.02 seconds
#
# Solving A-n37-k06.xml with Simulated Annealing
# Number of cities: 37
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 16, 4, 7, 18, 19, 14, 0]
# Route 2: [0, 20, 33, 5, 29, 36, 6, 8, 0]
# Route 3: [0, 31, 26, 10, 11, 34, 0]
# Route 4: [0, 25, 15, 32, 30, 13, 0]
# Route 5: [0, 27, 35, 28, 12, 22, 23, 0]
# Route 6: [0, 17, 9, 21, 2, 1, 3, 0]
# Total distance: 1340.47
# Execution time: 0.01 seconds
#
# Solving A-n38-k05.xml with Simulated Annealing
# Number of cities: 38
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 24, 14, 2, 13, 36, 17, 9, 21, 19, 12, 0]
# Route 2: [0, 32, 20, 7, 5, 22, 27, 31, 33, 0]
# Route 3: [0, 10, 30, 29, 34, 6, 25, 0]
# Route 4: [0, 18, 28, 37, 11, 16, 4, 1, 0]
# Route 5: [0, 8, 23, 35, 26, 3, 15, 0]
# Total distance: 1084.61
# Execution time: 0.01 seconds
#
# Solving A-n39-k05.xml with Simulated Annealing
# Number of cities: 39
# Number of vehicles: 5
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 4, 18, 9, 12, 31, 0]
# Route 2: [0, 19, 33, 1, 20, 23, 29, 5, 16, 32, 3, 38, 8, 0]
# Route 3: [0, 21, 30, 13, 28, 6, 36, 27, 34, 0]
# Route 4: [0, 11, 17, 26, 24, 35, 2, 0]
# Route 5: [0, 25, 15, 10, 7, 22, 37, 0]
# Total distance: 1032.57
# Execution time: 0.01 seconds
#
# Solving A-n39-k06.xml with Simulated Annealing
# Number of cities: 39
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 15, 13, 30, 5, 0]
# Route 2: [0, 24, 3, 38, 12, 37, 31, 14, 33, 23, 0]
# Route 3: [0, 26, 11, 6, 1, 36, 17, 21, 0]
# Route 4: [0, 29, 28, 9, 20, 32, 18, 22, 34, 27, 7, 0]
# Route 5: [0, 8, 2, 19, 4, 16, 35, 0]
# Route 6: [0, 10, 25, 0]
# Total distance: 1212.89
# Execution time: 0.01 seconds
#
# Solving A-n44-k06.xml with Simulated Annealing
# Number of cities: 44
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 31, 8, 15, 28, 27, 19, 24, 0]
# Route 2: [0, 4, 34, 17, 12, 3, 6, 22, 9, 38, 21, 0]
# Route 3: [0, 2, 41, 14, 36, 25, 39, 0]
# Route 4: [0, 7, 5, 33, 10, 11, 26, 30, 40, 0]
# Route 5: [0, 29, 43, 23, 20, 16, 18, 0]
# Route 6: [0, 13, 1, 35, 37, 42, 32, 0]
# Total distance: 1328.69
# Execution time: 0.01 seconds
#
# Solving A-n45-k06.xml with Simulated Annealing
# Number of cities: 45
# Number of vehicles: 6
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 9, 28, 7, 32, 13, 20, 10, 0]
# Route 2: [0, 14, 35, 1, 44, 6, 26, 11, 19, 2, 0]
# Route 3: [0, 38, 25, 12, 15, 22, 42, 4, 41, 0]
# Route 4: [0, 29, 43, 18, 17, 27, 5, 0]
# Route 5: [0, 31, 24, 37, 34, 40, 0]
# Route 6: [0, 3, 8, 33, 21, 16, 36, 39, 0]
# Total distance: 1345.59
# Execution time: 0.01 seconds
#
# Solving A-n45-k07.xml with Simulated Annealing
# Number of cities: 45
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 35, 39, 34, 26, 4, 21, 2, 8, 38, 0]
# Route 2: [0, 12, 32, 13, 18, 7, 16, 20, 40, 0]
# Route 3: [0, 9, 10, 15, 25, 23, 42, 14, 0]
# Route 4: [0, 24, 44, 33, 31, 5, 0]
# Route 5: [0, 28, 3, 11, 43, 41, 27, 0]
# Route 6: [0, 17, 22, 30, 19, 0]
# Route 7: [0, 6, 29, 36, 37, 1, 0]
# Total distance: 1395.23
# Execution time: 0.01 seconds
#
# Solving A-n46-k07.xml with Simulated Annealing
# Number of cities: 46
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 23, 9, 28, 17, 21, 41, 20, 27, 1, 33, 36, 0]
# Route 2: [0, 38, 14, 43, 6, 26, 13, 30, 5, 3, 45, 0]
# Route 3: [0, 32, 22, 39, 7, 10, 18, 0]
# Route 4: [0, 4, 2, 37, 44, 11, 0]
# Route 5: [0, 19, 8, 15, 16, 24, 42, 0]
# Route 6: [0, 12, 35, 25, 40, 34, 31, 0]
# Route 7: [0, 29, 0]
# Total distance: 1335.79
# Execution time: 0.02 seconds
#
# Solving A-n48-k07.xml with Simulated Annealing
# Number of cities: 48
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 17, 18, 44, 35, 23, 43, 31, 32, 0]
# Route 2: [0, 41, 47, 16, 10, 2, 29, 34, 0]
# Route 3: [0, 12, 5, 1, 6, 22, 7, 42, 0]
# Route 4: [0, 40, 36, 37, 19, 38, 25, 0]
# Route 5: [0, 45, 27, 15, 8, 39, 26, 3, 0]
# Route 6: [0, 28, 9, 24, 4, 13, 30, 21, 46, 11, 0]
# Route 7: [0, 33, 20, 0]
# Total distance: 1476.57
# Execution time: 0.02 seconds
#
# Solving A-n53-k07.xml with Simulated Annealing
# Number of cities: 53
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 1, 4, 28, 22, 30, 44, 46, 8, 27, 29, 25, 0]
# Route 2: [0, 31, 20, 6, 35, 38, 18, 51, 39, 0]
# Route 3: [0, 33, 3, 5, 14, 34, 7, 0]
# Route 4: [0, 47, 9, 17, 41, 11, 24, 52, 0]
# Route 5: [0, 12, 45, 2, 37, 36, 50, 43, 23, 19, 15, 49, 0]
# Route 6: [0, 21, 13, 16, 32, 48, 40, 0]
# Route 7: [0, 10, 26, 42, 0]
# Total distance: 1449.54
# Execution time: 0.01 seconds
#
# Solving A-n54-k07.xml with Simulated Annealing
# Number of cities: 54
# Number of vehicles: 7
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 43, 4, 28, 5, 7, 39, 50, 20, 23, 0]
# Route 2: [0, 52, 30, 16, 6, 32, 13, 11, 38, 26, 35, 0]
# Route 3: [0, 18, 49, 29, 15, 10, 1, 36, 17, 45, 0]
# Route 4: [0, 34, 41, 46, 51, 42, 24, 2, 12, 27, 14, 0]
# Route 5: [0, 25, 47, 37, 8, 19, 31, 33, 0]
# Route 6: [0, 44, 53, 3, 22, 0]
# Route 7: [0, 9, 21, 40, 48, 0]
# Total distance: 1433.64
# Execution time: 0.01 seconds
#
# Solving A-n55-k09.xml with Simulated Annealing
# Number of cities: 55
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 8, 21, 12, 32, 10, 5, 40, 0]
# Route 2: [0, 25, 41, 29, 18, 48, 50, 44, 0]
# Route 3: [0, 4, 7, 42, 31, 26, 46, 14, 16, 0]
# Route 4: [0, 37, 3, 17, 34, 33, 20, 0]
# Route 5: [0, 30, 22, 19, 27, 13, 28, 54, 0]
# Route 6: [0, 53, 38, 47, 39, 9, 35, 1, 0]
# Route 7: [0, 36, 2, 51, 11, 15, 43, 0]
# Route 8: [0, 6, 45, 0]
# Route 9: [0, 23, 52, 24, 49, 0]
# Total distance: 1427.81
# Execution time: 0.01 seconds
#
# Solving A-n60-k09.xml with Simulated Annealing
# Number of cities: 60
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 41, 18, 33, 52, 19, 59, 38, 55, 50, 0]
# Route 2: [0, 16, 20, 25, 46, 40, 11, 4, 21, 6, 2, 49, 32, 0]
# Route 3: [0, 14, 47, 23, 34, 24, 58, 35, 0]
# Route 4: [0, 3, 31, 28, 44, 1, 36, 22, 27, 0]
# Route 5: [0, 15, 39, 26, 17, 57, 37, 5, 0]
# Route 6: [0, 7, 29, 8, 13, 56, 0]
# Route 7: [0, 53, 30, 10, 54, 45, 0]
# Route 8: [0, 48, 42, 9, 51, 0]
# Route 9: [0, 43, 12, 0]
# Total distance: 1968.10
# Execution time: 0.02 seconds
#
# Solving A-n61-k09.xml with Simulated Annealing
# Number of cities: 61
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 14, 7, 23, 19, 15, 0]
# Route 2: [0, 9, 51, 39, 13, 50, 12, 22, 4, 26, 27, 0]
# Route 3: [0, 55, 33, 42, 32, 43, 30, 3, 0]
# Route 4: [0, 17, 57, 52, 31, 60, 11, 44, 56, 0]
# Route 5: [0, 28, 1, 16, 48, 35, 18, 47, 6, 0]
# Route 6: [0, 24, 10, 38, 0]
# Route 7: [0, 58, 25, 40, 20, 41, 8, 46, 0]
# Route 8: [0, 34, 21, 29, 36, 53, 2, 59, 0]
# Route 9: [0, 49, 37, 45, 5, 54, 0]
# Total distance: 1421.16
# Execution time: 0.01 seconds
#
# Solving A-n62-k08.xml with Simulated Annealing
# Number of cities: 62
# Number of vehicles: 8
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 28, 15, 7, 20, 51, 10, 61, 29, 6, 13, 0]
# Route 2: [0, 53, 12, 48, 56, 14, 5, 60, 31, 34, 25, 11, 4, 21, 41, 54, 18, 0]
# Route 3: [0, 52, 36, 16, 37, 22, 44, 2, 38, 0]
# Route 4: [0, 19, 30, 1, 9, 42, 55, 17, 0]
# Route 5: [0, 40, 32, 57, 59, 26, 50, 0]
# Route 6: [0, 8, 43, 33, 58, 35, 45, 0]
# Route 7: [0, 46, 47, 24, 3, 39, 0]
# Route 8: [0, 49, 23, 27, 0]
# Total distance: 1816.58
# Execution time: 0.02 seconds
#
# Solving A-n63-k09.xml with Simulated Annealing
# Number of cities: 63
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 26, 19, 7, 56, 15, 44, 16, 13, 49, 0]
# Route 2: [0, 11, 33, 12, 28, 22, 58, 0]
# Route 3: [0, 20, 25, 60, 61, 48, 42, 31, 46, 0]
# Route 4: [0, 54, 29, 30, 2, 34, 5, 27, 52, 0]
# Route 5: [0, 10, 6, 37, 17, 35, 51, 50, 55, 47, 1, 0]
# Route 6: [0, 53, 21, 32, 40, 14, 57, 62, 0]
# Route 7: [0, 36, 8, 59, 24, 39, 0]
# Route 8: [0, 45, 3, 41, 9, 4, 0]
# Route 9: [0, 23, 43, 38, 18, 0]
# Total distance: 2248.57
# Execution time: 0.01 seconds
#
# Solving A-n63-k10.xml with Simulated Annealing
# Number of cities: 63
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 48, 36, 52, 30, 4, 50, 29, 0]
# Route 2: [0, 20, 26, 13, 28, 57, 44, 7, 0]
# Route 3: [0, 17, 62, 31, 24, 21, 61, 54, 40, 45, 0]
# Route 4: [0, 38, 43, 10, 59, 5, 18, 49, 15, 39, 0]
# Route 5: [0, 25, 56, 53, 14, 1, 41, 42, 19, 11, 0]
# Route 6: [0, 32, 47, 34, 51, 58, 22, 23, 0]
# Route 7: [0, 16, 37, 60, 8, 27, 0]
# Route 8: [0, 46, 55, 0]
# Route 9: [0, 3, 2, 9, 12, 0]
# Route 10: [0, 33, 35, 6, 0]
# Total distance: 1933.26
# Execution time: 0.01 seconds
#
# Solving A-n64-k09.xml with Simulated Annealing
# Number of cities: 64
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 6, 10, 41, 56, 52, 13, 61, 24, 16, 9, 0]
# Route 2: [0, 25, 29, 45, 15, 11, 57, 27, 7, 0]
# Route 3: [0, 33, 48, 42, 20, 23, 37, 59, 0]
# Route 4: [0, 38, 18, 22, 12, 43, 28, 26, 0]
# Route 5: [0, 53, 3, 62, 30, 31, 40, 0]
# Route 6: [0, 32, 19, 51, 34, 4, 46, 36, 0]
# Route 7: [0, 17, 1, 14, 35, 21, 44, 39, 55, 8, 0]
# Route 8: [0, 60, 47, 63, 58, 2, 54, 0]
# Route 9: [0, 5, 50, 49, 0]
# Total distance: 1962.22
# Execution time: 0.02 seconds
#
# Solving A-n65-k09.xml with Simulated Annealing
# Number of cities: 65
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 51, 17, 47, 34, 31, 26, 46, 11, 48, 19, 0]
# Route 2: [0, 39, 62, 28, 23, 57, 63, 7, 45, 0]
# Route 3: [0, 49, 43, 15, 27, 14, 22, 4, 35, 61, 32, 0]
# Route 4: [0, 64, 6, 9, 3, 36, 42, 0]
# Route 5: [0, 5, 55, 29, 18, 21, 25, 52, 10, 0]
# Route 6: [0, 54, 33, 1, 12, 13, 24, 59, 0]
# Route 7: [0, 30, 37, 60, 50, 16, 41, 0]
# Route 8: [0, 53, 44, 56, 8, 38, 0]
# Route 9: [0, 20, 58, 40, 2, 0]
# Total distance: 1802.41
# Execution time: 0.01 seconds
#
# Solving A-n69-k09.xml with Simulated Annealing
# Number of cities: 69
# Number of vehicles: 9
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 19, 24, 43, 52, 26, 54, 5, 46, 0]
# Route 2: [0, 28, 34, 14, 42, 57, 11, 63, 37, 16, 1, 10, 0]
# Route 3: [0, 7, 27, 65, 55, 60, 4, 47, 25, 29, 2, 0]
# Route 4: [0, 31, 18, 53, 9, 30, 51, 3, 15, 44, 6, 0]
# Route 5: [0, 58, 22, 12, 66, 23, 41, 0]
# Route 6: [0, 67, 64, 61, 21, 33, 49, 13, 20, 0]
# Route 7: [0, 62, 56, 39, 8, 59, 0]
# Route 8: [0, 50, 48, 36, 17, 32, 0]
# Route 9: [0, 68, 38, 40, 45, 35, 0]
# Total distance: 1575.52
# Execution time: 0.02 seconds
#
# Solving A-n80-k10.xml with Simulated Annealing
# Number of cities: 80
# Number of vehicles: 10
# Vehicle capacity: 100.0
#
# Solution routes:
# Route 1: [0, 49, 73, 36, 42, 51, 77, 3, 29, 31, 0]
# Route 2: [0, 40, 21, 1, 7, 10, 71, 14, 33, 0]
# Route 3: [0, 13, 53, 66, 67, 70, 38, 58, 50, 76, 0]
# Route 4: [0, 74, 60, 39, 17, 27, 59, 0]
# Route 5: [0, 62, 23, 44, 12, 5, 30, 6, 0]
# Route 6: [0, 63, 11, 34, 24, 2, 37, 8, 68, 0]
# Route 7: [0, 72, 45, 22, 32, 4, 54, 9, 15, 64, 47, 0]
# Route 8: [0, 52, 28, 79, 48, 18, 78, 20, 0]
# Route 9: [0, 46, 25, 41, 55, 56, 69, 65, 35, 26, 19, 75, 16, 0]
# Route 10: [0, 61, 57, 43, 0]
# Total distance: 2255.46
# Execution time: 0.02 seconds
